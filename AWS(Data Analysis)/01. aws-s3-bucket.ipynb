# %%
# pip install boto3

# %%
# pip install s3fs

# %%
import boto3
import pandas as pd
print("Module Loaded")
# Out:
# Module Loaded

# %%
s3 = boto3.resource(
    service_name='s3',
    region_name='ap-south-1',
    aws_access_key_id='XXXX',
    aws_secret_access_key='XXXX'
)

print("DONE")
# Out:
# DONE

# %%
for i in s3.buckets.all():
    print(i)
    print(i.name)
# Out:
# s3.Bucket(name='header-s3-demo-bucket')
# header-s3-demo-bucket
# s3.Bucket(name='myapp-hospital-storage')
# myapp-hospital-storage
# s3.Bucket(name='mycompany-dev-storage')
# mycompany-dev-storage
# s3.Bucket(name='tamana-bucket-aws')
# tamana-bucket-aws

# %%
file = s3.Bucket('header-s3-demo-bucket').Object('students.csv').get()

# %%
file
# Out:
# {'ResponseMetadata': {'RequestId': 'NTEDGTX9TRJYQ1S8',
#   'HostId': 'Rgu6GzOCRAW3G7KrgbUXZJO46JlhaWzCaeuR5F8av03qPjsisf+/MrIC7w6LhA6RKyZAIGXP3/M=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'Rgu6GzOCRAW3G7KrgbUXZJO46JlhaWzCaeuR5F8av03qPjsisf+/MrIC7w6LhA6RKyZAIGXP3/M=',
#    'x-amz-request-id': 'NTEDGTX9TRJYQ1S8',
#    'date': 'Fri, 13 Mar 2026 04:10:22 GMT',
#    'last-modified': 'Fri, 13 Mar 2026 04:08:39 GMT',
#    'etag': '"c88ef9d93dc9015184db130e4fdd6660"',
#    'x-amz-checksum-crc64nvme': 'kczjTBYivOw=',
#    'x-amz-checksum-type': 'FULL_OBJECT',
#    'x-amz-server-side-encryption': 'AES256',
#    'accept-ranges': 'bytes',
#    'content-type': 'text/csv',
#    'content-length': '1628',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'AcceptRanges': 'bytes',
#  'LastModified': datetime.datetime(2026, 3, 13, 4, 8, 39, tzinfo=tzutc()),
#  'ContentLength': 1628,
#  'ETag': '"c88ef9d93dc9015184db130e4fdd6660"',
#  'ChecksumCRC64NVME': 'kczjTBYivOw=',
# ...

# %%
file['Body']

# %%
df = pd.read_csv(file['Body'])
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df = pd.read_csv(file['Body'])
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...
