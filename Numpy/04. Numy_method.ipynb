# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# np.concatenate
# np.stack
# slicing and assignment

# %%
virat = plt.imread(r"C:\Users\Admin\Desktop\download (1).jfif")

# %%
virat_arr = virat.copy()

# %%
virat_arr
# Out:
# array([[[203, 217, 204],
#         [203, 217, 204],
#         [203, 217, 204],
#         ...,
#         [201, 217, 207],
#         [201, 217, 207],
#         [201, 217, 207]],
#
#        [[203, 217, 204],
#         [203, 217, 204],
#         [203, 217, 204],
#         ...,
#         [201, 217, 207],
#         [201, 217, 207],
#         [201, 217, 207]],
#
#        [[203, 217, 204],
#         [203, 217, 204],
#         [203, 217, 204],
#         ...,
#         [201, 217, 207],
#         [201, 217, 207],
#         [201, 217, 207]],
#
#        ...,
#
#        [[251, 159,  86],
#         [251, 159,  86],
#         [252, 158,  86],
#         ...,
#         [229, 115,  53],
#         [226, 126,  66],
#         [232, 132,  72]],
#
#        [[251, 159,  86],
#         [252, 158,  86],
#         [252, 158,  86],
#         ...,
#         [229, 115,  53],
#         [223, 123,  63],
#         [229, 129,  69]],
#
#        [[252, 158,  86],
#         [252, 158,  86],
#         [253, 156,  85],
# ...

# %%
virat_arr.ndim
# Out:
# 3

# %%
virat_arr.max()
# Out:
# np.uint8(255)

# %%
virat_arr.min()
# Out:
# np.uint8(0)

# %%
plt.imshow(virat_arr)

# %%
virat_arr.shape
# Out:
# (260, 194, 3)

# %%
a = virat_arr

# %%
a[:,:,0]  # this channnel is Red
# Out:
# array([[203, 203, 203, ..., 201, 201, 201],
#        [203, 203, 203, ..., 201, 201, 201],
#        [203, 203, 203, ..., 201, 201, 201],
#        ...,
#        [251, 251, 252, ..., 229, 226, 232],
#        [251, 252, 252, ..., 229, 223, 229],
#        [252, 252, 253, ..., 229, 222, 228]], shape=(260, 194), dtype=uint8)

# %%
a[:,:,1] # this channel is green
# Out:
# array([[217, 217, 217, ..., 217, 217, 217],
#        [217, 217, 217, ..., 217, 217, 217],
#        [217, 217, 217, ..., 217, 217, 217],
#        ...,
#        [159, 159, 158, ..., 115, 126, 132],
#        [159, 158, 158, ..., 115, 123, 129],
#        [158, 158, 156, ..., 115, 119, 125]], shape=(260, 194), dtype=uint8)

# %%
a[:,:,2] # this channel is blue
# Out:
# array([[204, 204, 204, ..., 207, 207, 207],
#        [204, 204, 204, ..., 207, 207, 207],
#        [204, 204, 204, ..., 207, 207, 207],
#        ...,
#        [ 86,  86,  86, ...,  53,  66,  72],
#        [ 86,  86,  86, ...,  53,  63,  69],
#        [ 86,  86,  85, ...,  53,  60,  66]], shape=(260, 194), dtype=uint8)

# %%
plt.imshow(a[:,:,2])  # to indicate blue

# %%
plt.imshow(a[:,:,1]) # to indicate green

# %%
plt.imshow(a[:,:,0]) # to indicate red

# %%
# html color code of ref : (255,87,51)

# %%
b= [255,0,0]

# %%
a[:,:,0] = 0

# %%
a
# Out:
# array([[[  0, 217, 204],
#         [  0, 217, 204],
#         [  0, 217, 204],
#         ...,
#         [  0, 217, 207],
#         [  0, 217, 207],
#         [  0, 217, 207]],
#
#        [[  0, 217, 204],
#         [  0, 217, 204],
#         [  0, 217, 204],
#         ...,
#         [  0, 217, 207],
#         [  0, 217, 207],
#         [  0, 217, 207]],
#
#        [[  0, 217, 204],
#         [  0, 217, 204],
#         [  0, 217, 204],
#         ...,
#         [  0, 217, 207],
#         [  0, 217, 207],
#         [  0, 217, 207]],
#
#        ...,
#
#        [[  0, 159,  86],
#         [  0, 159,  86],
#         [  0, 158,  86],
#         ...,
#         [  0, 115,  53],
#         [  0, 126,  66],
#         [  0, 132,  72]],
#
#        [[  0, 159,  86],
#         [  0, 158,  86],
#         [  0, 158,  86],
#         ...,
#         [  0, 115,  53],
#         [  0, 123,  63],
#         [  0, 129,  69]],
#
#        [[  0, 158,  86],
#         [  0, 158,  86],
#         [  0, 156,  85],
# ...

# %%
plt.imshow(a)

# %%
a[:,:,0] = 255

# %%
plt.imshow(a)

# %%
a[:,:,1] = 0

# %%
plt.imshow(a)

# %%
a[:,:,1] = 0

# %%
plt.imshow(a)

# %%
a[:,:,2] = 255

# %%
plt.imshow(a)

# %%
virat_arr
# Out:
# array([[[255,   0, 255],
#         [255,   0, 255],
#         [255,   0, 255],
#         ...,
#         [255,   0, 255],
#         [255,   0, 255],
#         [255,   0, 255]],
#
#        [[255,   0, 255],
#         [255,   0, 255],
#         [255,   0, 255],
#         ...,
#         [255,   0, 255],
#         [255,   0, 255],
#         [255,   0, 255]],
#
#        [[255,   0, 255],
#         [255,   0, 255],
#         [255,   0, 255],
#         ...,
#         [255,   0, 255],
#         [255,   0, 255],
#         [255,   0, 255]],
#
#        ...,
#
#        [[255,   0, 255],
#         [255,   0, 255],
#         [255,   0, 255],
#         ...,
#         [255,   0, 255],
#         [255,   0, 255],
#         [255,   0, 255]],
#
#        [[255,   0, 255],
#         [255,   0, 255],
#         [255,   0, 255],
#         ...,
#         [255,   0, 255],
#         [255,   0, 255],
#         [255,   0, 255]],
#
#        [[255,   0, 255],
#         [255,   0, 255],
#         [255,   0, 255],
# ...

# %%
a.shape
# Out:
# (260, 194, 3)

# %%
b = virat

# %%
b
# Out:
# array([[[203, 217, 204],
#         [203, 217, 204],
#         [203, 217, 204],
#         ...,
#         [201, 217, 207],
#         [201, 217, 207],
#         [201, 217, 207]],
#
#        [[203, 217, 204],
#         [203, 217, 204],
#         [203, 217, 204],
#         ...,
#         [201, 217, 207],
#         [201, 217, 207],
#         [201, 217, 207]],
#
#        [[203, 217, 204],
#         [203, 217, 204],
#         [203, 217, 204],
#         ...,
#         [201, 217, 207],
#         [201, 217, 207],
#         [201, 217, 207]],
#
#        ...,
#
#        [[251, 159,  86],
#         [251, 159,  86],
#         [252, 158,  86],
#         ...,
#         [229, 115,  53],
#         [226, 126,  66],
#         [232, 132,  72]],
#
#        [[251, 159,  86],
#         [252, 158,  86],
#         [252, 158,  86],
#         ...,
#         [229, 115,  53],
#         [223, 123,  63],
#         [229, 129,  69]],
#
#        [[252, 158,  86],
#         [252, 158,  86],
#         [253, 156,  85],
# ...

# %%
plt.imshow(b)

# %%
c = b

# %%
c
# Out:
# array([[[203, 217, 204],
#         [203, 217, 204],
#         [203, 217, 204],
#         ...,
#         [201, 217, 207],
#         [201, 217, 207],
#         [201, 217, 207]],
#
#        [[203, 217, 204],
#         [203, 217, 204],
#         [203, 217, 204],
#         ...,
#         [201, 217, 207],
#         [201, 217, 207],
#         [201, 217, 207]],
#
#        [[203, 217, 204],
#         [203, 217, 204],
#         [203, 217, 204],
#         ...,
#         [201, 217, 207],
#         [201, 217, 207],
#         [201, 217, 207]],
#
#        ...,
#
#        [[251, 159,  86],
#         [251, 159,  86],
#         [252, 158,  86],
#         ...,
#         [229, 115,  53],
#         [226, 126,  66],
#         [232, 132,  72]],
#
#        [[251, 159,  86],
#         [252, 158,  86],
#         [252, 158,  86],
#         ...,
#         [229, 115,  53],
#         [223, 123,  63],
#         [229, 129,  69]],
#
#        [[252, 158,  86],
#         [252, 158,  86],
#         [253, 156,  85],
# ...

# %%
plt.imshow(c)

# %%
c[180:230,130:160:]
# Out:
# array([[[ 59,  84, 174],
#         [ 53,  78, 168],
#         [ 52,  77, 167],
#         ...,
#         [ 70, 104, 194],
#         [ 73, 107, 197],
#         [ 74, 108, 198]],
#
#        [[ 58,  83, 173],
#         [ 54,  79, 169],
#         [ 53,  78, 168],
#         ...,
#         [ 76, 110, 200],
#         [ 73, 107, 197],
#         [ 70, 104, 194]],
#
#        [[ 59,  84, 174],
#         [ 61,  86, 176],
#         [ 62,  87, 177],
#         ...,
#         [ 74, 108, 198],
#         [ 70, 104, 194],
#         [ 67, 101, 191]],
#
#        ...,
#
#        [[ 80, 115, 205],
#         [ 72, 107, 197],
#         [ 57,  92, 182],
#         ...,
#         [ 58,  78, 165],
#         [ 42,  62, 149],
#         [ 37,  57, 143]],
#
#        [[ 75, 110, 200],
#         [ 67, 102, 192],
#         [ 59,  94, 184],
#         ...,
#         [ 49,  71, 147],
#         [ 44,  63, 139],
#         [ 43,  63, 136]],
#
#        [[ 62,  97, 187],
#         [ 61,  96, 186],
#         [ 68, 103, 193],
# ...

# %%
plt.imshow(c[180:230,130:160:])

# %%
b
# Out:
# array([[[203, 217, 204],
#         [203, 217, 204],
#         [203, 217, 204],
#         ...,
#         [201, 217, 207],
#         [201, 217, 207],
#         [201, 217, 207]],
#
#        [[203, 217, 204],
#         [203, 217, 204],
#         [203, 217, 204],
#         ...,
#         [201, 217, 207],
#         [201, 217, 207],
#         [201, 217, 207]],
#
#        [[203, 217, 204],
#         [203, 217, 204],
#         [203, 217, 204],
#         ...,
#         [201, 217, 207],
#         [201, 217, 207],
#         [201, 217, 207]],
#
#        ...,
#
#        [[251, 159,  86],
#         [251, 159,  86],
#         [252, 158,  86],
#         ...,
#         [229, 115,  53],
#         [226, 126,  66],
#         [232, 132,  72]],
#
#        [[251, 159,  86],
#         [252, 158,  86],
#         [252, 158,  86],
#         ...,
#         [229, 115,  53],
#         [223, 123,  63],
#         [229, 129,  69]],
#
#        [[252, 158,  86],
#         [252, 158,  86],
#         [253, 156,  85],
# ...

# %%
plt.imshow(b)

# %%
plt.imshow(b[20:140,50:150,:])

# %%
plt.imshow(b[20:140,50:150,:] // 3)

# %%
flg = plt.imread(r"C:\Users\Admin\Desktop\download.png")

# %%
flg
# Out:
# array([[[1.        , 0.40784314, 0.1254902 , 1.        ],
#         [1.        , 0.40784314, 0.1254902 , 1.        ],
#         [1.        , 0.40784314, 0.1254902 , 1.        ],
#         ...,
#         [1.        , 0.40784314, 0.1254902 , 1.        ],
#         [1.        , 0.40784314, 0.1254902 , 1.        ],
#         [1.        , 0.40784314, 0.1254902 , 1.        ]],
#
#        [[1.        , 0.40784314, 0.1254902 , 1.        ],
#         [1.        , 0.40784314, 0.1254902 , 1.        ],
#         [1.        , 0.40784314, 0.1254902 , 1.        ],
#         ...,
#         [1.        , 0.40784314, 0.1254902 , 1.        ],
#         [1.        , 0.40784314, 0.1254902 , 1.        ],
#         [1.        , 0.40784314, 0.1254902 , 1.        ]],
#
#        [[1.        , 0.40784314, 0.1254902 , 1.        ],
#         [1.        , 0.40784314, 0.1254902 , 1.        ],
#         [1.        , 0.40784314, 0.1254902 , 1.        ],
#         ...,
# ...

# %%
plt.imshow(flg)

# %%
plt.imshow(flg[50:100,85:135])

# %%
flg.shape
# Out:
# (148, 222, 4)

# %%
plt.imshow(flg[50:100,85:135]/3)

# %%
plt.imshow(flg[50:100,85:135])

# %%
a = np.array([[1,2,3],[3,4,5],[4,8,9]])

# %%
np.random.seed(1)
b = np.random.randint(1,5,(3,3))

# %%
b
# Out:
# array([[2, 4, 1],
#        [1, 4, 2],
#        [4, 2, 4]], dtype=int32)

# %%
np.stack((a,b),axis=0)
# Out:
# array([[[1, 2, 3],
#         [3, 4, 5],
#         [4, 8, 9]],
#
#        [[2, 4, 1],
#         [1, 4, 2],
#         [4, 2, 4]]])

# %%
np.stack((a,b),axis=1)
# Out:
# array([[[1, 2, 3],
#         [2, 4, 1]],
#
#        [[3, 4, 5],
#         [1, 4, 2]],
#
#        [[4, 8, 9],
#         [4, 2, 4]]])

# %%
np.stack((a,b),axis=1).shape
# Out:
# (3, 2, 3)

# %%
np.stack((a,b),axis=2)
# Out:
# array([[[1, 2],
#         [2, 4],
#         [3, 1]],
#
#        [[3, 1],
#         [4, 4],
#         [5, 2]],
#
#        [[4, 4],
#         [8, 2],
#         [9, 4]]])

# %%
np.stack((a,b),axis=1).shape
# Out:
# (3, 2, 3)

# %%
plt.imshow(a)

# %%
plt.imshow(b)

# %%
plt.imshow(np.stack((a,b),axis=0))

# %%
# np.concatenate()

# %%
virat
# Out:
# array([[[203, 217, 204],
#         [203, 217, 204],
#         [203, 217, 204],
#         ...,
#         [201, 217, 207],
#         [201, 217, 207],
#         [201, 217, 207]],
#
#        [[203, 217, 204],
#         [203, 217, 204],
#         [203, 217, 204],
#         ...,
#         [201, 217, 207],
#         [201, 217, 207],
#         [201, 217, 207]],
#
#        [[203, 217, 204],
#         [203, 217, 204],
#         [203, 217, 204],
#         ...,
#         [201, 217, 207],
#         [201, 217, 207],
#         [201, 217, 207]],
#
#        ...,
#
#        [[251, 159,  86],
#         [251, 159,  86],
#         [252, 158,  86],
#         ...,
#         [229, 115,  53],
#         [226, 126,  66],
#         [232, 132,  72]],
#
#        [[251, 159,  86],
#         [252, 158,  86],
#         [252, 158,  86],
#         ...,
#         [229, 115,  53],
#         [223, 123,  63],
#         [229, 129,  69]],
#
#        [[252, 158,  86],
#         [252, 158,  86],
#         [253, 156,  85],
# ...

# %%
np.concatenate([a,b])
# Out:
# array([[1, 2, 3],
#        [3, 4, 5],
#        [4, 8, 9],
#        [2, 4, 1],
#        [1, 4, 2],
#        [4, 2, 4]])

# %%
plt.imshow(virat)

# %%
a = virat

# %%
plt.imshow(np.concatenate((a, a), axis=0))

# %%
plt.imshow(np.concatenate((a, a), axis=1))

# %%
final_image = np.concatenate((a,a))

# %%
final_image.shape
# Out:
# (520, 194, 3)

# %%
plt.imshow(np.concatenate((final_image,)*2))

# %%
plt.imshow(np.concatenate((final_image,)*4,axis=1))
