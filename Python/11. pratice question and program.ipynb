# %% [markdown]
# # Random Password Generator

# %%
import random
import string

# %%
string.ascii_letters
# Out:
# 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
string.ascii_lowercase
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
string.ascii_uppercase
# Out:
# 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
string.digits
# Out:
# '0123456789'

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
chars = string.ascii_letters + string.digits + string.punctuation

# %%
chars
# Out:
# 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
print(chars)
# Out:
# abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
type(chars)
# Out:
# str

# %%
passoword = ''.join(random.choices(chars,k=12))

# %%
passoword
# Out:
# 'jW2)tCq&n5+f'

# %%
import random
import string

length = int(input("Enter password length: "))

chars = string.ascii_letters + string.digits + string.punctuation

password = ''.join(random.choices(chars, k=length))

print("Password:", password)
# Out:
# Enter password length:  7
# Password: .-zv=i=

# %%
main = ['a', 'b', 'c', 'd']
a= ''.join(main)

print(a)
# Out:
# abcd

# %%
type(a)
# Out:
# str

# %%
main = ['a', 'b', 'c', 'd']
a=''.join(main)

print(a)
# Out:
# abcd

# %%
## Join nhi krne pe result

# %%
import random
import string

length = int(input("Enter password length: "))

chars = string.ascii_letters + string.digits + string.punctuation

password = (random.choices(chars, k=length))

print("Password:", password)
# Out:
# Enter password length:  4
# Password: ['/', 'Y', 'R', '7']

# %% [markdown]
# # triangle / circle / square

# %%
shape = input("Enter shape (triangle, circle, square): ").lower()

if shape == "triangle":
    base = float(input("Enter base: "))
    height = float(input("Enter height: "))
    area = 0.5 * base * height
    print("Area of triangle:", area)

elif shape == "circle":
    radius = float(input("Enter radius: "))
    area = 3.14 * radius * radius
    print("Area of circle:", area)

elif shape == "square":
    side = float(input("Enter side: "))
    area = side * side
    print("Area of square:", area)

else:
    print("Invalid shape")
# Out:
# Enter shape (triangle, circle, square):  Triangle
# Enter base:  33
# Enter height:  33
# Area of triangle: 544.5

# %% [markdown]
# # Simple Calculator

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
op = input("Enter operator (+,-,*,/): ")

if op == "+":
    print(a + b)
elif op == "-":
    print(a - b)
elif op == "*":
    print(a * b)
elif op == "/":
    print(a / b)
else:
    print("Invalid operator")
# Out:
# Enter first number:  33
# Enter second number:  33
# Enter operator (+,-,*,/):  *
# 1089

# %% [markdown]
# # Palindrome Checker

# %%
word = input("Enter word: ")

if word == word[::-1]:
    print("Palindrome")
else:
    print("Not palindrome")
# Out:
# Enter word:  222
# Palindrome

# %% [markdown]
# # Vowel or Consonant Checker

# %%
ch = input("Enter character: ")

vowels = ('a','e','i','o','u')

if ch.lower() in vowels:
    print("Vowel")
else:
    print("Consonant")
# Out:
# Enter character:  y
# Consonant

# %% [markdown]
# # Word Length Checker

# %%
word = input("Enter word: ")

if len(word) > 5:
    print("Long word")
else:
    print("Short word")
# Out:
# Enter word:  fffffffffffff
# Long word

# %% [markdown]
# # Login System

# %%
users = {"admin":"1234", "user":"abcd"}

name = input("Enter username: ")
password = input("Enter password: ")

if name in users and users[name] == password:
    print("Login successful")
else:
    print("Invalid login")
# Out:
# Enter username:  admin
# Enter password:  abcd
# Invalid login

# %% [markdown]
# # Fruit Price Checker

# %%
fruits = {
    "apple":100,
    "banana":40,
    "mango":80
}

f = input("Enter fruit name: ")

if f in fruits:
    print("Price:", fruits[f])
else:
    print("Fruit not available")
# Out:
# Enter fruit name:  banana
# Price: 40

# %% [markdown]
# 1. Even or Odd
#
# Take a number from the user and check whether it is even or odd.
#
# 2. Positive, Negative, or Zero
#
# Take a number and check if it is positive, negative, or zero.
#
# 3. Largest of Two Numbers
#
# Take two numbers from the user and print the larger number.
#
# 4. Largest of Three Numbers
#
# Take three numbers and find the largest number using if-elif-else.
#
# 5. Vowel or Consonant
#
# Take a character from the user and check if it is a vowel or consonant.
#
# 6. Check Palindrome
#
# Take a word and check whether it is a palindrome or not.
#
# Example:
# madam → palindrome
#
# 7. Check Username and Password
#
# Create a dictionary of usernames and passwords.
# Check if the entered username and password are correct.
#
# 8. Fruit Price Finder
#
# Store fruit prices in a dictionary.
# Ask the user for a fruit name and print its price.
#
# 9. Check Element in List
#
# Create a list of numbers.
# Ask the user for a number and check if it exists in the list.
#
# 10. Word Length Checker
#
# Take a word and check if its length is greater than 5 or not.
#
# 11. Uppercase or Lowercase
#
# Take a letter and check whether it is uppercase or lowercase.
#
# 12. Day of the Week
#
# Store the days of the week in a tuple.
# Ask the user for a number (1–7) and print the corresponding day.
#
# 13. Student Grade System
#
# Take marks as input and print grade:
#
# 90+ → A
#
# 75–89 → B
#
# 50–74 → C
#
# below 50 → Fail
#
# 14. Check Empty String
#
# Take a string from the user and check if it is empty or not.
#
# 15. Password Length Checker
#
# Take a password and check if its length is at least 8 characters.
#
# 16. Check First Letter
#
# Take a word and check if the first letter is a vowel.
#
# 17. Country Capital Finder
#
# Create a dictionary of countries and capitals.
# Ask the user for a country name and print its capital.
#
# 18. Temperature Checker
#
# Take temperature as input and print:
#
# Below 15 → Cold
#
# 15–30 → Normal
#
# Above 30 → Hot
#
# 19. Check Number in Tuple
#
# Create a tuple of numbers.
# Check if a given number exists in the tuple.
#
# 20. Email Checker
#
# Take an email from the user and check if it contains "@" and ".".
