# %% [markdown]
# # String Mehod

# %%
a = "Munna Kumar From India"

# %%
print(a)
# Out:
# Munna Kumar From India

# %%
# find  : find out index

# %%
a.find('I')
# Out:
# 17

# %%
a[17:]
# Out:
# 'India'

# %%
a[a.find('I'):]
# Out:
# 'India'

# %%
a.find('M')
# Out:
# 0

# %%
a[0:a.find('I')]
# Out:
# 'Munna Kumar From '

# %%
a.find('a')
# Out:
# 4

# %%
a.find('a',5)
# Out:
# 9

# %%
b = "Python is Awesome"

# %%
b.find('o')
# Out:
# 4

# %%
b.find('o',5)
# Out:
# 14

# %%
b[b.find('o',5):]
# Out:
# 'ome'

# %%
b
# Out:
# 'Python is Awesome'

# %%
a.find('z')
# Out:
# -1

# %%
b
# Out:
# 'Python is Awesome'

# %%
b.index('A')
# Out:
# 10

# %%
b.index('Z')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 b.index('Z')
#
# ValueError: substring not found

# %%
# find jo value nhi uske liye (-1) deta h
# index jo value nhi hota hai uske liye error de deta h

# %% [markdown]
# # formate

# %%
name = "Munna Kumar"
hobby = "Playing Cricket"
year = 2001

# %%
print(f"My name is {name} and my hobby is {hobby} and by born year is {year}")
# Out:
# My name is Munna Kumar and my hobby is Playing Cricket and by born year is 2001

# %%
c = "My name is {} and my hobby is {}".format(name,hobby)

# %%
print(c)
# Out:
# My name is Munna Kumar and my hobby is Playing Cricket

# %% [markdown]
# # Starting with is

# %%
# jitne bhi method is se start hote uska anwser BOLLEAN mai aata h

# %%
a
# Out:
# 'Munna Kumar From India'

# %%
a.isalnum()
# Out:
# False

# %%
b
# Out:
# 'Python is Awesome'

# %%
b.isdigit()
# Out:
# False

# %%
c= "100"

# %%
c.isdigit()
# Out:
# True

# %%
d = "Munna7"

# %%
d.isalpha()
# Out:
# False

# %%
a = '😊' # window + .  add emjoi

# %%
a.isascii()
# Out:
# False

# %% [markdown]
# ![download.jpg](attachment:658a6662-9239-4bd8-a7fa-4fac8034b1d6.jpg)

# %%
chr(62)
# Out:
# '>'

# %%
chr(95)
# Out:
# '_'

# %%
chr(127)
# Out:
# '\x7f'

# %%
chr(126)
# Out:
# '~'

# %%
a
# Out:
# '😊'

# %%
b
# Out:
# 'Python is Awesome'

# %%
# a.join()
# a.captialize()
# a.center()
# a.count()
# a.endswith()
# a.format()
# a.isalpha()
# a.join()
# a.lower()
# a.lstrip()
# a.partition()
# a.removeprefix()
# a.removesuffix()
# a.replace()
# a.split()
# a.startswith()
# a.strip()
# a.swapcase()
# a.upper()
# a.zfill()
# a.title()

# %%
# a.join()
msg = ["My","Name","Is","Munna"]
ans = ' '
print(ans.join(msg))
# Out:
# My Name Is Munna

# %%
msg = "Munna"

msg.upper()
# Out:
# 'MUNNA'

# %%
ans = ' '
ans.join(msg)
# Out:
# 'M u n n a'

# %%
# a.endswith()
a = "Munna Kumar"
a.endswith("ar")
# Out:
# True

# %%
a.endswith("are")
# Out:
# False

# %%
# a.strip()

a = '   This is munna  '
a.rstrip()
# Out:
# '   This is munna'

# %%
a.lstrip()
# Out:
# 'This is munna  '

# %%
a.strip()
# Out:
# 'This is munna'

# %% [markdown]
# # a.partiton() --> only 3 part
# # a.split() --> Multiple part

# %%
a.partition('is')
# Out:
# ('   Th', 'is', ' is munna  ')

# %%
a.partition('munna')
# Out:
# ('   This is ', 'munna', '  ')

# %%
a = "  Munna Kumar  "

# %%
a.split(' ')
# Out:
# ['', '', 'Munna', 'Kumar', '', '']
