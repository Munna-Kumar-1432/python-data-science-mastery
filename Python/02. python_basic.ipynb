# %% [markdown]
# # Python Basic

# %%
help('keywords')
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %% [markdown]
# # Python Syntax

# %%
# Roadmap
# Basic Python
# Intermediate Python
# Advance Python
# Data Analysis Modules
# Numpy
# Pandas
# Matplotlib
# Seaborn
# Plotly : Adv

# %% [markdown]
# # Basic Python

# %%
# How to write code
# Syntax
# Rules
# Data Types

# %%
x = 23
y = 34
z = x + y
print(z)
# Out:
# 57

# %%
# x : Varibale/ Identifier
# 23 : value/Literals

# %% [markdown]
# # Data Types

# %%
# Numberical data types : -
# i. Integer
# ii. Float
# iii. Complex

# %%
data = 123
print(data)
# Out:
# 123

# %%
type(data)
# Out:
# int

# %%
# type: Datatype batata hai

# %%
a = 45.95
print(a)
print(type(a))
# Out:
# 45.95
# <class 'float'>

# %%
a = 3 + 4j
print(a)
print(type(a))
# Out:
# (3+4j)
# <class 'complex'>

# %% [markdown]
# # Text data type : String

# %%
# koi bhi data agar qoutes ke andar likh diya woo string mai aa jayega

# %%
a = "Munna Kumar"
print(a)
print(type(a))
# Out:
# Munna Kumar
# <class 'str'>

# %%
a = 'Munna Kumar'
print(a)
print(type(a))
# Out:
# Munna Kumar
# <class 'str'>

# %%
a = '''Munna Kumar'''
print(a)
print(type(a))
# Out:
# Munna Kumar
# <class 'str'>

# %%
a ="""Munna Kumar"""
print(a)
print(type(a))
# Out:
# Munna Kumar
# <class 'str'>

# %% [markdown]
# # Sequential Data Type(Tuple)

# %%
# ROund braces

# %%
a = 12,22,2,3,4,5
print(a)
print(type(a))
# Out:
# (12, 22, 2, 3, 4, 5)
# <class 'tuple'>

# %%
a = (1,2,344,4)
print(a)
print(type(a))
# Out:
# (1, 2, 344, 4)
# <class 'tuple'>

# %% [markdown]
# # List Data Type
# - Collection data type
# - Square brackets

# %%
a = [1,2,3,"Munna Kumar"]
print(a)
print(type(a))
# Out:
# [1, 2, 3, 'Munna Kumar']
# <class 'list'>

# %% [markdown]
# # Unorder Data Type
# Set Data Type

# %%
a = {1,244,344,44,5}
print(a)
print(type(a))
# Out:
# {1, 244, 5, 344, 44}
# <class 'set'>

# %% [markdown]
# # Boolean Data type

# %%
a = True
print(a)
print(type(a))
# Out:
# True
# <class 'bool'>

# %% [markdown]
# # Advanced Data Type
# hash data type
# mapping data type
# Dict data type

# %%
a = {"name":"Munna Kumar","age":23,"roll":1}
print(a)
print(type(a))
# Out:
# {'name': 'Munna Kumar', 'age': 23, 'roll': 1}
# <class 'dict'>

# %% [markdown]
# # special Data Type
# - None

# %%
a = None
print(a)
print(type(a))
# Out:
# None
# <class 'NoneType'>

# %% [markdown]
# ![Python-data-types.webp](attachment:c5519e0c-7216-4ae5-906b-26711dafed9c.webp)

# %%
# Python is an object open sourse orinted general purpose programming language with dyanmic symantic

# %%
# Dynamic Syntex : run time pe data type bata dena

# %%
# object Orinted : Object OOPS
# Withoit object Orinted : Object : OOPS

# %% [markdown]
# # Variable Naming Rule
# - It can not start digit
# - Varibale name must not conatin any white spaces
# - We can use underscore at any position
# - We can use after first index
# - Python is case sensitive(lower and upper differnent diff)
# - We can not  use any special charcters except underscore
# - Keywords not allowed for variable declerations

# %%
# Variable must name use to easy to understand
