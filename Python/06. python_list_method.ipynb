# %% [markdown]
# # List Method

# %%
a = [10,20,30,40]

# %%
# pop
# copy
# remove
# reverse
# sort

# %%
a.pop()
# Out:
# 30

# %%
a
# Out:
# [10, 20]

# %%
a = [10,20,30,40,50]

# %%
a
# Out:
# [10, 20, 30, 40, 50]

# %%
a.remove(10)

# %%
a
# Out:
# [20, 30, 40, 50]

# %%
print(a)
# Out:
# [20, 30, 40, 50]

# %%
a = [10,20,30,10,10,30]

# %%
a.remove(10)  ## Remove First Element

# %%
a
# Out:
# [20, 30, 10, 10, 30]

# %%
a.remove(10)

# %%
a
# Out:
# [20, 30, 10, 30]

# %%
a.remove(10)

# %%
a
# Out:
# [20, 30, 30]

# %%
student =["Munna","Raunak","Amit","Virat"]

# %%
student
# Out:
# ['Munna', 'Raunak', 'Amit', 'Virat']

# %%
student.remove('Amit')

# %%
student
# Out:
# ['Munna', 'Raunak', 'Virat']

# %%
student =["Munna","Raunak","Amit","Virat","Munna","Munna"]

# %%
student.index("Munna")
# Out:
# 0

# %%
student.index("Munna",2)
# Out:
# 4

# %%
student.index("Munna",4)
# Out:
# 4

# %%
student[4]
# Out:
# 'Munna'

# %%
del student[4]

# %%
student
# Out:
# ['Munna', 'Raunak', 'Amit', 'Virat', 'Munna']

# %%
del(student[4])

# %%
student
# Out:
# ['Munna', 'Raunak', 'Amit', 'Virat']

# %%
## remove

# %%
student
# Out:
# ['Munna', 'Raunak', 'Amit', 'Virat']

# %%
student.append("India")

# %%
student
# Out:
# ['Munna', 'Raunak', 'Amit', 'Virat', 'India']

# %%
# !python -V
# Out:
# Python 3.13.9

# %%
student
# Out:
# ['Munna', 'Raunak', 'Amit', 'Virat', 'India']

# %%
student[2:4]
# Out:
# ['Amit', 'Virat']

# %%
student[2:4] = [student[2:4]]

# %%
student
# Out:
# ['Munna', 'Raunak', ['Amit', 'Virat'], 'India']

# %%
student.remove(['Amit', 'Virat'])

# %%
student
# Out:
# ['Munna', 'Raunak', 'India']

# %%
print(student)
# Out:
# ['Munna', 'Raunak', 'India']

# %%
# reverse
# sort
# copy

# %%
a =["Munna","Raunak","Amit","Virat","Munna","Munna"]

# %%
print(a.reverse())
# Out:
# None

# %%
a
# Out:
# ['Munna', 'Munna', 'Virat', 'Amit', 'Raunak', 'Munna']

# %%
a
# Out:
# ['Munna', 'Munna', 'Virat', 'Amit', 'Raunak', 'Munna']

# %%
a[::-1]
# Out:
# ['Munna', 'Raunak', 'Amit', 'Virat', 'Munna', 'Munna']

# %%
a  = [1,3,4,2,4,5,6,67,8]

# %%
a.sort()

# %%
print(a)
# Out:
# [1, 2, 3, 4, 4, 5, 6, 8, 67]

# %%
a.reverse()

# %%
print(a)
# Out:
# [67, 8, 6, 5, 4, 4, 3, 2, 1]

# %%
a
# Out:
# [67, 8, 6, 5, 4, 4, 3, 2, 1]

# %%
a.sort(reverse=True)

# %%
print(a)
# Out:
# [67, 8, 6, 5, 4, 4, 3, 2, 1]

# %%
## Copy Method

# %%
a = [10,20,30,40]

# %%
b = a.copy()

# %%
b
# Out:
# [10, 20, 30, 40]

# %%
b.reverse()

# %%
print(b)
# Out:
# [40, 30, 20, 10]

# %%
## Deep COpy

# %%
a = [1200,2300]
b = a

# %%
print(a)
# Out:
# [1200, 2300]

# %%
print(b)
# Out:
# [1200, 2300]

# %%
a[-1] = 1222

# %%
print(a)
# Out:
# [1200, 1222]

# %%
print(b)
# Out:
# [1200, 1222]

# %%
## Above are Deep copy

# %%
a = [10,20]

# %%
b = a.copy()

# %%
print(a)
# Out:
# [10, 20]

# %%
print(b)
# Out:
# [10, 20]

# %%
a[-1] = 234

# %%
print(a)
# Out:
# [10, 234]

# %%
print(b)
# Out:
# [10, 20]

# %%
## Above are shallow copy

# %%
id(a)
# Out:
# 2115825303808

# %%
id(b)
# Out:
# 2115825346048

# %%
# Python is memory sufficinet programaing languagae

# %%
bytes(b)
# Out:
# b'\n\x14'

# %%
memoryview(bytes(b))
