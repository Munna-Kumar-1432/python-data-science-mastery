# %%
## IPL DATASET

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
print("Module Loaded Succeefully !!")
# Out:
# Module Loaded Succeefully !!

# %%
df = pd.read_csv(r"C:\Users\Admin\Desktop\data\IPL\IPL Matches 2008-2020.csv")

# %%
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df.columns
# Out:
# Index(['id', 'city', 'date', 'player_of_match', 'venue', 'neutral_venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'eliminator', 'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
df.head()
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %%
df.tail()
# Out:
#           id       city        date player_of_match  \
# 811  1216547      Dubai  2020-09-28  AB de Villiers
# 812  1237177      Dubai  2020-11-05       JJ Bumrah
# 813  1237178  Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180  Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181      Dubai  2020-11-10        TA Boult
#
#                                    venue  neutral_venue  \
# 811  Dubai International Cricket Stadium              0
# 812  Dubai International Cricket Stadium              0
# 813                 Sheikh Zayed Stadium              0
# 814                 Sheikh Zayed Stadium              0
# 815  Dubai International Cricket Stadium              0
#
#                            team1                team2          toss_winner  \
# 811  Royal Challengers Bangalore       Mumbai Indians       Mumbai Indians
# 812               Mumbai Indians       Delhi Capitals       Delhi Capitals
# 813  Royal Challengers Bangalore  Sunrisers Hyderabad  Sunrisers Hyderabad
# ...

# %%
df.sample()
# Out:
#          id    city        date player_of_match              venue  \
# 510  829811  Mumbai  2015-05-16       SR Watson  Brabourne Stadium
#
#      neutral_venue             team1                  team2       toss_winner  \
# 510              0  Rajasthan Royals  Kolkata Knight Riders  Rajasthan Royals
#
#     toss_decision            winner result  result_margin eliminator method  \
# 510           bat  Rajasthan Royals   runs            9.0          N    NaN
#
#           umpire1         umpire2
# 510  RM Deshpande  RK Illingworth

# %%
df.head(1)
# Out:
#        id       city        date player_of_match                  venue  \
# 0  335982  Bangalore  2008-04-18     BB McCullum  M Chinnaswamy Stadium
#
#    neutral_venue                        team1                  team2  \
# 0              0  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                    toss_winner toss_decision                 winner result  \
# 0  Royal Challengers Bangalore         field  Kolkata Knight Riders   runs
#
#    result_margin eliminator method    umpire1      umpire2
# 0          140.0          N    NaN  Asad Rauf  RE Koertzen

# %%
df.nunique()
# Out:
# id                 816
# city                32
# date               596
# player_of_match    233
# venue               36
# neutral_venue        2
# team1               15
# team2               15
# toss_winner         15
# toss_decision        2
# winner              15
# result               3
# result_margin       91
# eliminator           2
# method               1
# umpire1             48
# umpire2             47
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
df.isna().sum() ## that means in city 13 data are missing and playerofthematch 4 data are missing
# Out:
# id                   0
# city                13
# date                 0
# player_of_match      4
# venue                0
# neutral_venue        0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               4
# result               4
# result_margin       17
# eliminator           4
# method             797
# umpire1              0
# umpire2              0
# dtype: int64

# %%
(df.isna().sum()/len(df))*100
# Out:
# id                  0.000000
# city                1.593137
# date                0.000000
# player_of_match     0.490196
# venue               0.000000
# neutral_venue       0.000000
# team1               0.000000
# team2               0.000000
# toss_winner         0.000000
# toss_decision       0.000000
# winner              0.490196
# result              0.490196
# result_margin       2.083333
# eliminator          0.490196
# method             97.671569
# umpire1             0.000000
# umpire2             0.000000
# dtype: float64

# %%
## Thoda thoda missing ko data hum discard kr skate h

# %%
df.shape
# Out:
# (816, 17)

# %%
# 2 or 3 percent data ka cut le skta hu main

# %%
df.columns
# Out:
# Index(['id', 'city', 'date', 'player_of_match', 'venue', 'neutral_venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'eliminator', 'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
df.dropna().shape ## ye gaalt kyukyu method mai 97 percent missing hai isi karn 3 percent hi data aaya h
# Out:
# (19, 17)

# %%
df['method'].unique()
# Out:
# array([nan, 'D/L'], dtype=object)

# %%
df.fillna({'method':'fare_match'})
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
ipl1 = df.fillna({'method':'fare_match'})

# %%
ipl1.isna().sum()
# Out:
# id                  0
# city               13
# date                0
# player_of_match     4
# venue               0
# neutral_venue       0
# team1               0
# team2               0
# toss_winner         0
# toss_decision       0
# winner              4
# result              4
# result_margin      17
# eliminator          4
# method              0
# umpire1             0
# umpire2             0
# dtype: int64

# %%
ipl2 = ipl1.dropna()

# %%
ipl2
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 810  1216546       Dubai  2020-10-20        S Dhawan
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
ipl2.isna().sum()
# Out:
# id                 0
# city               0
# date               0
# player_of_match    0
# venue              0
# neutral_venue      0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# winner             0
# result             0
# result_margin      0
# eliminator         0
# method             0
# umpire1            0
# umpire2            0
# dtype: int64

# %%
ipl2['city']
# Out:
# 0       Bangalore
# 1      Chandigarh
# 2           Delhi
# 3          Mumbai
# 4         Kolkata
#           ...
# 810         Dubai
# 812         Dubai
# 813     Abu Dhabi
# 814     Abu Dhabi
# 815         Dubai
# Name: city, Length: 786, dtype: object

# %%
ipl2['city'].unique()
# Out:
# array(['Bangalore', 'Chandigarh', 'Delhi', 'Mumbai', 'Kolkata', 'Jaipur',
#        'Hyderabad', 'Chennai', 'Cape Town', 'Port Elizabeth', 'Durban',
#        'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Bloemfontein', 'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala',
#        'Kochi', 'Indore', 'Visakhapatnam', 'Pune', 'Raipur', 'Ranchi',
#        'Abu Dhabi', 'Rajkot', 'Kanpur', 'Bengaluru', 'Sharjah', 'Dubai'],
#       dtype=object)

# %%
ipl2.describe()
# Out:
#                  id  neutral_venue  result_margin
# count  7.860000e+02     786.000000     786.000000
# mean   7.538069e+05       0.078880      17.418575
# std    3.078221e+05       0.269724      22.120149
# min    3.359820e+05       0.000000       1.000000
# 25%    5.012222e+05       0.000000       6.000000
# 50%    6.636760e+05       0.000000       8.000000
# 75%    1.082627e+06       0.000000      20.000000
# max    1.237181e+06       1.000000     146.000000

# %%
ipl2.describe(include="object")
# Out:
#           city        date player_of_match         venue  \
# count      786         786             786           786
# unique      32         578             232            36
# top     Mumbai  2014-05-13  AB de Villiers  Eden Gardens
# freq       100           2              22            77
#
#                               team1           team2     toss_winner  \
# count                           786             786             786
# unique                           15              15              15
# top     Royal Challengers Bangalore  Mumbai Indians  Mumbai Indians
# freq                            101             101             100
#
#        toss_decision          winner   result eliminator      method  \
# count            786             786      786        786         786
# unique             2              15        2          1           2
# top            field  Mumbai Indians  wickets          N  fare_match
# ...

# %%
ipl2.info() ## Yaha dekho date object mai isko Date mai convert krna hoga
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 786 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               786 non-null    int64
#  1   city             786 non-null    object
#  2   date             786 non-null    object
#  3   player_of_match  786 non-null    object
#  4   venue            786 non-null    object
#  5   neutral_venue    786 non-null    int64
#  6   team1            786 non-null    object
#  7   team2            786 non-null    object
#  8   toss_winner      786 non-null    object
#  9   toss_decision    786 non-null    object
#  10  winner           786 non-null    object
#  11  result           786 non-null    object
#  12  result_margin    786 non-null    float64
#  13  eliminator       786 non-null    object
#  14  method           786 non-null    object
#  15  umpire1          786 non-null    object
#  16  umpire2          786 non-null    object
# ...

# %%
## Change Datat Type

# %%
ipl2['date'] = pd.to_datetime(ipl2['date'])
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18280\521442899.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipl2['date'] = pd.to_datetime(ipl2['date'])

# %%
ipl2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 786 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               786 non-null    int64
#  1   city             786 non-null    object
#  2   date             786 non-null    datetime64[ns]
#  3   player_of_match  786 non-null    object
#  4   venue            786 non-null    object
#  5   neutral_venue    786 non-null    int64
#  6   team1            786 non-null    object
#  7   team2            786 non-null    object
#  8   toss_winner      786 non-null    object
#  9   toss_decision    786 non-null    object
#  10  winner           786 non-null    object
#  11  result           786 non-null    object
#  12  result_margin    786 non-null    float64
#  13  eliminator       786 non-null    object
#  14  method           786 non-null    object
#  15  umpire1          786 non-null    object
# ...

# %%
ipl2.describe()
# Out:
#                  id                           date  neutral_venue  \
# count  7.860000e+02                            786     786.000000
# mean   7.538069e+05  2014-03-29 04:18:19.236641280       0.078880
# min    3.359820e+05            2008-04-18 00:00:00       0.000000
# 25%    5.012222e+05            2011-04-22 06:00:00       0.000000
# 50%    6.636760e+05            2013-11-04 12:00:00       0.000000
# 75%    1.082627e+06            2017-04-30 00:00:00       0.000000
# max    1.237181e+06            2020-11-10 00:00:00       1.000000
# std    3.078221e+05                            NaN       0.269724
#
#        result_margin
# count     786.000000
# mean       17.418575
# min         1.000000
# 25%         6.000000
# 50%         8.000000
# 75%        20.000000
# max       146.000000
# std        22.120149

# %%
ipl2['city'].value_counts() ## Kis city m kitne match hua h
# Out:
# city
# Mumbai            100
# Kolkata            77
# Delhi              72
# Hyderabad          63
# Bangalore          62
# Chandigarh         56
# Chennai            56
# Jaipur             47
# Pune               38
# Abu Dhabi          27
# Dubai              23
# Durban             15
# Bengaluru          14
# Visakhapatnam      13
# Centurion          12
# Sharjah            12
# Ahmedabad          11
# Dharamsala          9
# Rajkot              9
# Indore              9
# Johannesburg        8
# Cuttack             7
# Port Elizabeth      7
# Ranchi              7
# Raipur              6
# Cape Town           6
# Kochi               5
# Kanpur              4
# Nagpur              3
# East London         3
# Kimberley           3
# Bloemfontein        2
# Name: count, dtype: int64

# %%
ipl2['city'].value_counts().head().plot(kind='bar')
# Out:
# <Axes: xlabel='city'>

# %%
ipl2['city'].value_counts().tail().plot(kind='bar')
# Out:
# <Axes: xlabel='city'>

# %%
ipl2.shape[0]
# Out:
# 786

# %%
df.shape
# Out:
# (816, 17)

# %%
ipl2.sample()
# Out:
#          id   city       date player_of_match             venue  \
# 344  598020  Delhi 2013-04-18      MEK Hussey  Feroz Shah Kotla
#
#      neutral_venue             team1                team2  \
# 344              0  Delhi Daredevils  Chennai Super Kings
#
#              toss_winner toss_decision               winner result  \
# 344  Chennai Super Kings           bat  Chennai Super Kings   runs
#
#      result_margin eliminator      method    umpire1      umpire2
# 344           86.0          N  fare_match  M Erasmus  VA Kulkarni

# %%
ipl2['city'].unique()
# Out:
# array(['Bangalore', 'Chandigarh', 'Delhi', 'Mumbai', 'Kolkata', 'Jaipur',
#        'Hyderabad', 'Chennai', 'Cape Town', 'Port Elizabeth', 'Durban',
#        'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Bloemfontein', 'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala',
#        'Kochi', 'Indore', 'Visakhapatnam', 'Pune', 'Raipur', 'Ranchi',
#        'Abu Dhabi', 'Rajkot', 'Kanpur', 'Bengaluru', 'Sharjah', 'Dubai'],
#       dtype=object)

# %%
ipl3 = ipl2.replace({"Bengaluru":"Bangalore"})

# %%
ipl3['city'].value_counts()
# Out:
# city
# Mumbai            100
# Kolkata            77
# Bangalore          76
# Delhi              72
# Hyderabad          63
# Chandigarh         56
# Chennai            56
# Jaipur             47
# Pune               38
# Abu Dhabi          27
# Dubai              23
# Durban             15
# Visakhapatnam      13
# Centurion          12
# Sharjah            12
# Ahmedabad          11
# Dharamsala          9
# Rajkot              9
# Indore              9
# Johannesburg        8
# Cuttack             7
# Port Elizabeth      7
# Ranchi              7
# Raipur              6
# Cape Town           6
# Kochi               5
# Kanpur              4
# Nagpur              3
# East London         3
# Kimberley           3
# Bloemfontein        2
# Name: count, dtype: int64

# %%
ipl3['city'].unique()
# Out:
# array(['Bangalore', 'Chandigarh', 'Delhi', 'Mumbai', 'Kolkata', 'Jaipur',
#        'Hyderabad', 'Chennai', 'Cape Town', 'Port Elizabeth', 'Durban',
#        'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Bloemfontein', 'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala',
#        'Kochi', 'Indore', 'Visakhapatnam', 'Pune', 'Raipur', 'Ranchi',
#        'Abu Dhabi', 'Rajkot', 'Kanpur', 'Sharjah', 'Dubai'], dtype=object)

# %%
ipl3['city'].nunique()
# Out:
# 31

# %%
ipl3.sample()
# Out:
#          id        city       date player_of_match  \
# 117  419108  Chandigarh 2010-03-13       G Gambhir
#
#                                           venue  neutral_venue  \
# 117  Punjab Cricket Association Stadium, Mohali              0
#
#                team1             team2       toss_winner toss_decision  \
# 117  Kings XI Punjab  Delhi Daredevils  Delhi Daredevils         field
#
#                winner   result  result_margin eliminator      method  \
# 117  Delhi Daredevils  wickets            5.0          N  fare_match
#
#          umpire1 umpire2
# 117  BR Doctrove  S Ravi

# %%
ipl3['year'] = ipl3['date'].dt.year

# %%
ipl3
# Out:
#           id        city       date player_of_match  \
# 0     335982   Bangalore 2008-04-18     BB McCullum
# 1     335983  Chandigarh 2008-04-19      MEK Hussey
# 2     335984       Delhi 2008-04-19     MF Maharoof
# 3     335985      Mumbai 2008-04-20      MV Boucher
# 4     335986     Kolkata 2008-04-20       DJ Hussey
# ..       ...         ...        ...             ...
# 810  1216546       Dubai 2020-10-20        S Dhawan
# 812  1237177       Dubai 2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi 2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi 2020-11-08      MP Stoinis
# 815  1237181       Dubai 2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
ipl3.shape
# Out:
# (786, 18)

# %%
ipl3['month'] = ipl3['date'].dt.month

# %%
ipl3.sample()
# Out:
#           id       city       date player_of_match                 venue  \
# 787  1216523  Abu Dhabi 2020-10-10      KD Karthik  Sheikh Zayed Stadium
#
#      neutral_venue                  team1            team2  \
# 787              0  Kolkata Knight Riders  Kings XI Punjab
#
#                toss_winner toss_decision                 winner result  \
# 787  Kolkata Knight Riders           bat  Kolkata Knight Riders   runs
#
#      result_margin eliminator      method    umpire1      umpire2  year  month
# 787            2.0          N  fare_match  UV Gandhe  CB Gaffaney  2020     10

# %%
ipl3.shape
# Out:
# (786, 19)

# %%
ipl3['year'].describe()
# Out:
# count     786.000000
# mean     2013.884224
# std         3.684788
# min      2008.000000
# 25%      2011.000000
# 50%      2013.500000
# 75%      2017.000000
# max      2020.000000
# Name: year, dtype: float64

# %%
ipl3['year'].nunique()
# Out:
# 13

# %%
ipl3['year'].unique()
# Out:
# array([2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018,
#        2019, 2020], dtype=int32)

# %%
ipl3['year'].value_counts()
# Out:
# year
# 2012    74
# 2013    74
# 2011    72
# 2016    60
# 2018    60
# 2010    59
# 2008    58
# 2017    58
# 2019    57
# 2009    56
# 2015    56
# 2020    56
# 2014    46
# Name: count, dtype: int64

# %%
ipl3['year'].value_counts().sort_index()
# Out:
# year
# 2008    58
# 2009    56
# 2010    59
# 2011    72
# 2012    74
# 2013    74
# 2014    46
# 2015    56
# 2016    60
# 2017    58
# 2018    60
# 2019    57
# 2020    56
# Name: count, dtype: int64

# %%
ipl3['year'].value_counts().sort_index().plot()
# Out:
# <Axes: xlabel='year'>

# %%
ipl3['year'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='year'>

# %%
ipl3['year'].value_counts().sort_index().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
ipl3['month'].nunique()
# Out:
# 7

# %%
ipl3['month'].unique()
# Out:
# array([ 4,  5,  6,  3,  9, 10, 11], dtype=int32)

# %%
ipl3['month'].value_counts()
# Out:
# month
# 5     346
# 4     343
# 3      39
# 10     38
# 9      10
# 11      8
# 6       2
# Name: count, dtype: int64

# %%
ipl3['month'].value_counts().sort_index()
# Out:
# month
# 3      39
# 4     343
# 5     346
# 6       2
# 9      10
# 10     38
# 11      8
# Name: count, dtype: int64

# %%
ipl3['month'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='month'>

# %%
ipl3.columns
# Out:
# Index(['id', 'city', 'date', 'player_of_match', 'venue', 'neutral_venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'eliminator', 'method', 'umpire1', 'umpire2', 'year',
#        'month'],
#       dtype='object')

# %%
ipl3['player_of_match'].nunique()
# Out:
# 232

# %%
ipl3['player_of_match'].unique()
# Out:
# array(['BB McCullum', 'MEK Hussey', 'MF Maharoof', 'MV Boucher',
#        'DJ Hussey', 'SR Watson', 'V Sehwag', 'ML Hayden', 'YK Pathan',
#        'KC Sangakkara', 'JDP Oram', 'AC Gilchrist', 'SM Katich',
#        'MS Dhoni', 'ST Jayasuriya', 'GD McGrath', 'SE Marsh',
#        'SA Asnodkar', 'R Vinay Kumar', 'IK Pathan', 'SM Pollock',
#        'Sohail Tanvir', 'S Sreesanth', 'A Nehra', 'SC Ganguly',
#        'CRD Fernando', 'L Balaji', 'Shoaib Akhtar', 'A Mishra',
#        'DPMD Jayawardene', 'GC Smith', 'DJ Bravo', 'M Ntini',
#        'SP Goswami', 'A Kumble', 'KD Karthik', 'JA Morkel', 'P Kumar',
#        'Umar Gul', 'SK Raina', 'SR Tendulkar', 'R Dravid', 'DL Vettori',
#        'RP Singh', 'M Muralitharan', 'CH Gayle', 'AB de Villiers',
#        'RS Bopara', 'PP Ojha', 'TM Dilshan', 'HH Gibbs', 'DP Nannes',
#        'JP Duminy', 'Yuvraj Singh', 'SB Jakati', 'JH Kallis', 'G Gambhir',
#        'RG Sharma', 'A Singh', 'S Badrinath', 'DR Smith', 'LRPL Taylor',
# ...

# %%
player_match = ','.join(ipl3['player_of_match'].unique()).lower().split(',')

# %%
len(player_match)
# Out:
# 232

# %%
ipl3['player_of_match'].value_counts()
# Out:
# player_of_match
# AB de Villiers    22
# CH Gayle          22
# RG Sharma         18
# MS Dhoni          17
# DA Warner         17
#                   ..
# JEC Franklin       1
# Shoaib Akhtar      1
# S Aravind          1
# BA Bhatt           1
# PP Shaw            1
# Name: count, Length: 232, dtype: int64

# %%
ipl3['player_of_match'].value_counts().head(10)
# Out:
# player_of_match
# AB de Villiers    22
# CH Gayle          22
# RG Sharma         18
# MS Dhoni          17
# DA Warner         17
# SR Watson         16
# YK Pathan         15
# SK Raina          14
# G Gambhir         13
# V Kohli           12
# Name: count, dtype: int64

# %%
ipl3['player_of_match'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='player_of_match'>

# %%
ipl3['player_of_match'].value_counts().head(10).plot.pie(autopct='%.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
ipl3
# Out:
#           id        city       date player_of_match  \
# 0     335982   Bangalore 2008-04-18     BB McCullum
# 1     335983  Chandigarh 2008-04-19      MEK Hussey
# 2     335984       Delhi 2008-04-19     MF Maharoof
# 3     335985      Mumbai 2008-04-20      MV Boucher
# 4     335986     Kolkata 2008-04-20       DJ Hussey
# ..       ...         ...        ...             ...
# 810  1216546       Dubai 2020-10-20        S Dhawan
# 812  1237177       Dubai 2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi 2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi 2020-11-08      MP Stoinis
# 815  1237181       Dubai 2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
print(dir(pd))
# Out:
# ['ArrowDtype', 'BooleanDtype', 'Categorical', 'CategoricalDtype', 'CategoricalIndex', 'DataFrame', 'DateOffset', 'DatetimeIndex', 'DatetimeTZDtype', 'ExcelFile', 'ExcelWriter', 'Flags', 'Float32Dtype', 'Float64Dtype', 'Grouper', 'HDFStore', 'Index', 'IndexSlice', 'Int16Dtype', 'Int32Dtype', 'Int64Dtype', 'Int8Dtype', 'Interval', 'IntervalDtype', 'IntervalIndex', 'MultiIndex', 'NA', 'NaT', 'NamedAgg', 'Period', 'PeriodDtype', 'PeriodIndex', 'RangeIndex', 'Series', 'SparseDtype', 'StringDtype', 'Timedelta', 'TimedeltaIndex', 'Timestamp', 'UInt16Dtype', 'UInt32Dtype', 'UInt64Dtype', 'UInt8Dtype', '__all__', '__builtins__', '__cached__', '__doc__', '__docformat__', '__file__', '__git_version__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_built_with_meson', '_config', '_is_numpy_dev', '_libs', '_pandas_datetime_CAPI', '_pandas_parser_CAPI', '_testing', '_typing', '_version_meson', 'annotations', 'api', 'array', 'arrays', 'bdate_range', 'compat', 'con
# ...

# %%
print(dir(pd.DataFrame))
# Out:
# ['T', '_AXIS_LEN', '_AXIS_ORDERS', '_AXIS_TO_AXIS_NUMBER', '_HANDLED_TYPES', '__abs__', '__add__', '__and__', '__annotations__', '__array__', '__array_priority__', '__array_ufunc__', '__arrow_c_stream__', '__bool__', '__class__', '__contains__', '__copy__', '__dataframe__', '__dataframe_consortium_standard__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__divmod__', '__doc__', '__eq__', '__finalize__', '__firstlineno__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__imod__', '__imul__', '__init__', '__init_subclass__', '__invert__', '__ior__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pandas_priority__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce_
# ...

# %%
ipl3
# Out:
#           id        city       date player_of_match  \
# 0     335982   Bangalore 2008-04-18     BB McCullum
# 1     335983  Chandigarh 2008-04-19      MEK Hussey
# 2     335984       Delhi 2008-04-19     MF Maharoof
# 3     335985      Mumbai 2008-04-20      MV Boucher
# 4     335986     Kolkata 2008-04-20       DJ Hussey
# ..       ...         ...        ...             ...
# 810  1216546       Dubai 2020-10-20        S Dhawan
# 812  1237177       Dubai 2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi 2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi 2020-11-08      MP Stoinis
# 815  1237181       Dubai 2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
ipl3.columns
# Out:
# Index(['id', 'city', 'date', 'player_of_match', 'venue', 'neutral_venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'eliminator', 'method', 'umpire1', 'umpire2', 'year',
#        'month'],
#       dtype='object')

# %%
ipl3['venue'].nunique()
# Out:
# 36

# %%
ipl3['venue'].unique()
# Out:
# array(['M Chinnaswamy Stadium',
#        'Punjab Cricket Association Stadium, Mohali', 'Feroz Shah Kotla',
#        'Wankhede Stadium', 'Eden Gardens', 'Sawai Mansingh Stadium',
#        'Rajiv Gandhi International Stadium, Uppal',
#        'MA Chidambaram Stadium, Chepauk', 'Dr DY Patil Sports Academy',
#        'Newlands', "St George's Park", 'Kingsmead', 'SuperSport Park',
#        'Buffalo Park', 'New Wanderers Stadium', 'De Beers Diamond Oval',
#        'OUTsurance Oval', 'Brabourne Stadium',
#        'Sardar Patel Stadium, Motera', 'Barabati Stadium',
#        'Vidarbha Cricket Association Stadium, Jamtha',
#        'Himachal Pradesh Cricket Association Stadium', 'Nehru Stadium',
#        'Holkar Cricket Stadium',
#        'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium',
#        'Subrata Roy Sahara Stadium',
#        'Shaheed Veer Narayan Singh International Stadium',
#        'JSCA International Stadium Complex', 'Sheikh Zayed Stadium',
# ...

# %%
len(set(ipl3['venue']))
# Out:
# 36

# %%
ipl3['venue'].value_counts()
# Out:
# venue
# Eden Gardens                                            77
# Feroz Shah Kotla                                        72
# Wankhede Stadium                                        72
# Rajiv Gandhi International Stadium, Uppal               63
# M Chinnaswamy Stadium                                   62
# MA Chidambaram Stadium, Chepauk                         56
# Sawai Mansingh Stadium                                  47
# Punjab Cricket Association Stadium, Mohali              35
# Sheikh Zayed Stadium                                    27
# Dubai International Cricket Stadium                     23
# Punjab Cricket Association IS Bindra Stadium, Mohali    21
# Maharashtra Cricket Association Stadium                 21
# Dr DY Patil Sports Academy                              17
# Subrata Roy Sahara Stadium                              17
# Kingsmead                                               15
# M.Chinnaswamy Stadium                                   14
# ...

# %%
ipl3['venue'].str.lower()
# Out:
# 0                           m chinnaswamy stadium
# 1      punjab cricket association stadium, mohali
# 2                                feroz shah kotla
# 3                                wankhede stadium
# 4                                    eden gardens
#                           ...
# 810           dubai international cricket stadium
# 812           dubai international cricket stadium
# 813                          sheikh zayed stadium
# 814                          sheikh zayed stadium
# 815           dubai international cricket stadium
# Name: venue, Length: 786, dtype: object

# %%
ipl3['venue'].str.lower().nunique()
# Out:
# 36

# %%
ipl3['venue'].value_counts().head()
# Out:
# venue
# Eden Gardens                                 77
# Feroz Shah Kotla                             72
# Wankhede Stadium                             72
# Rajiv Gandhi International Stadium, Uppal    63
# M Chinnaswamy Stadium                        62
# Name: count, dtype: int64

# %%
ipl3['venue'].value_counts().head().plot(kind='bar')
# Out:
# <Axes: xlabel='venue'>

# %%
ipl3.columns
# Out:
# Index(['id', 'city', 'date', 'player_of_match', 'venue', 'neutral_venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'eliminator', 'method', 'umpire1', 'umpire2', 'year',
#        'month'],
#       dtype='object')

# %%
ipl3['neutral_venue'].nunique()
# Out:
# 2

# %%
ipl3['neutral_venue'].value_counts() ## kisi ka home ground hai ya nhi
# Out:
# neutral_venue
# 0    724
# 1     62
# Name: count, dtype: int64

# %%
ipl3[ipl3['neutral_venue'] == 1]
# Out:
#          id            city       date player_of_match                 venue  \
# 58   392181       Cape Town 2009-04-18    SR Tendulkar              Newlands
# 59   392182       Cape Town 2009-04-18        R Dravid              Newlands
# 60   392183       Cape Town 2009-04-19      DL Vettori              Newlands
# 61   392184       Cape Town 2009-04-19        RP Singh              Newlands
# 62   392185  Port Elizabeth 2009-04-20  M Muralitharan      St George's Park
# ..      ...             ...        ...             ...                   ...
# 400  729283       Abu Dhabi 2014-04-18      GJ Maxwell  Sheikh Zayed Stadium
# 401  729285       Abu Dhabi 2014-04-18       AM Rahane  Sheikh Zayed Stadium
# 405  729293       Abu Dhabi 2014-04-21        SK Raina  Sheikh Zayed Stadium
# 411  729305       Abu Dhabi 2014-04-26        PV Tambe  Sheikh Zayed Stadium
# 412  729307       Abu Dhabi 2014-04-26  Sandeep Sharma  Sheikh Zayed Stadium
#
# ...

# %%
ipl3[ipl3['neutral_venue'] == 0] ## Homeground hoga
# Out:
#           id        city       date player_of_match  \
# 0     335982   Bangalore 2008-04-18     BB McCullum
# 1     335983  Chandigarh 2008-04-19      MEK Hussey
# 2     335984       Delhi 2008-04-19     MF Maharoof
# 3     335985      Mumbai 2008-04-20      MV Boucher
# 4     335986     Kolkata 2008-04-20       DJ Hussey
# ..       ...         ...        ...             ...
# 810  1216546       Dubai 2020-10-20        S Dhawan
# 812  1237177       Dubai 2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi 2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi 2020-11-08      MP Stoinis
# 815  1237181       Dubai 2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
ipl3.columns
# Out:
# Index(['id', 'city', 'date', 'player_of_match', 'venue', 'neutral_venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'eliminator', 'method', 'umpire1', 'umpire2', 'year',
#        'month'],
#       dtype='object')

# %%
ipl3['team1']
# Out:
# 0      Royal Challengers Bangalore
# 1                  Kings XI Punjab
# 2                 Delhi Daredevils
# 3                   Mumbai Indians
# 4            Kolkata Knight Riders
#                   ...
# 810                 Delhi Capitals
# 812                 Mumbai Indians
# 813    Royal Challengers Bangalore
# 814                 Delhi Capitals
# 815                 Delhi Capitals
# Name: team1, Length: 786, dtype: object

# %%
ipl3['team1'].nunique()
# Out:
# 15

# %%
len(ipl3['team1'].unique())
# Out:
# 15

# %%
ipl3['team1'].str.lower().nunique()
# Out:
# 15

# %%
ipl3['team1'].value_counts()
# Out:
# team1
# Royal Challengers Bangalore    101
# Mumbai Indians                  94
# Chennai Super Kings             92
# Kolkata Knight Riders           91
# Kings XI Punjab                 90
# Delhi Daredevils                80
# Rajasthan Royals                67
# Sunrisers Hyderabad             56
# Deccan Chargers                 39
# Pune Warriors                   23
# Delhi Capitals                  17
# Gujarat Lions                   15
# Kochi Tuskers Kerala             7
# Rising Pune Supergiants          7
# Rising Pune Supergiant           7
# Name: count, dtype: int64

# %%
ipl3['team1'].value_counts().sum()
# Out:
# np.int64(786)

# %%
ipl4 = ipl3.replace({"Delhi Daredevils":"Delhi Capitals","Rising Pune Supergiants":"Rising Pune Supergiant","Deccan Chargers":"Sunrisers Hyderabad"})

# %%
ipl4.columns
# Out:
# Index(['id', 'city', 'date', 'player_of_match', 'venue', 'neutral_venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'eliminator', 'method', 'umpire1', 'umpire2', 'year',
#        'month'],
#       dtype='object')

# %%
ipl4['team1'].value_counts()
# Out:
# team1
# Royal Challengers Bangalore    101
# Delhi Capitals                  97
# Sunrisers Hyderabad             95
# Mumbai Indians                  94
# Chennai Super Kings             92
# Kolkata Knight Riders           91
# Kings XI Punjab                 90
# Rajasthan Royals                67
# Pune Warriors                   23
# Gujarat Lions                   15
# Rising Pune Supergiant          14
# Kochi Tuskers Kerala             7
# Name: count, dtype: int64

# %%
ipl4['team1'].value_counts().sum()
# Out:
# np.int64(786)

# %%
# Domain Ananlysis = Domain Knowledge

# %%
ipl4.groupby('team1')

# %%
ipl4.groupby('team1').count()
# Out:
#                               id  city  date  player_of_match  venue  \
# team1
# Chennai Super Kings           92    92    92               92     92
# Delhi Capitals                97    97    97               97     97
# Gujarat Lions                 15    15    15               15     15
# Kings XI Punjab               90    90    90               90     90
# Kochi Tuskers Kerala           7     7     7                7      7
# Kolkata Knight Riders         91    91    91               91     91
# Mumbai Indians                94    94    94               94     94
# Pune Warriors                 23    23    23               23     23
# Rajasthan Royals              67    67    67               67     67
# Rising Pune Supergiant        14    14    14               14     14
# Royal Challengers Bangalore  101   101   101              101    101
# Sunrisers Hyderabad           95    95    95               95     95
#
# ...

# %%
ipl4.groupby('team1')['id'].count().sort_values(ascending=False)
# Out:
# team1
# Royal Challengers Bangalore    101
# Delhi Capitals                  97
# Sunrisers Hyderabad             95
# Mumbai Indians                  94
# Chennai Super Kings             92
# Kolkata Knight Riders           91
# Kings XI Punjab                 90
# Rajasthan Royals                67
# Pune Warriors                   23
# Gujarat Lions                   15
# Rising Pune Supergiant          14
# Kochi Tuskers Kerala             7
# Name: id, dtype: int64

# %%
ipl2['team2'].value_counts()
# Out:
# team2
# Mumbai Indians                 101
# Kolkata Knight Riders           95
# Kings XI Punjab                 93
# Rajasthan Royals                87
# Royal Challengers Bangalore     84
# Chennai Super Kings             82
# Delhi Daredevils                74
# Sunrisers Hyderabad             61
# Deccan Chargers                 36
# Pune Warriors                   22
# Gujarat Lions                   14
# Delhi Capitals                  14
# Rising Pune Supergiant           9
# Kochi Tuskers Kerala             7
# Rising Pune Supergiants          7
# Name: count, dtype: int64

# %%
ipl4['team2'].value_counts().sort_index()
# Out:
# team2
# Chennai Super Kings             82
# Delhi Capitals                  88
# Gujarat Lions                   14
# Kings XI Punjab                 93
# Kochi Tuskers Kerala             7
# Kolkata Knight Riders           95
# Mumbai Indians                 101
# Pune Warriors                   22
# Rajasthan Royals                87
# Rising Pune Supergiant          16
# Royal Challengers Bangalore     84
# Sunrisers Hyderabad             97
# Name: count, dtype: int64

# %%
ipl4['team1'].value_counts().sort_index()
# Out:
# team1
# Chennai Super Kings             92
# Delhi Capitals                  97
# Gujarat Lions                   15
# Kings XI Punjab                 90
# Kochi Tuskers Kerala             7
# Kolkata Knight Riders           91
# Mumbai Indians                  94
# Pune Warriors                   23
# Rajasthan Royals                67
# Rising Pune Supergiant          14
# Royal Challengers Bangalore    101
# Sunrisers Hyderabad             95
# Name: count, dtype: int64

# %%
(ipl4['team1'].value_counts().sort_index() + ipl4['team2'].value_counts().sort_index()).sort_values(ascending=False)
# Out:
# team1
# Mumbai Indians                 195
# Sunrisers Hyderabad            192
# Kolkata Knight Riders          186
# Delhi Capitals                 185
# Royal Challengers Bangalore    185
# Kings XI Punjab                183
# Chennai Super Kings            174
# Rajasthan Royals               154
# Pune Warriors                   45
# Rising Pune Supergiant          30
# Gujarat Lions                   29
# Kochi Tuskers Kerala            14
# Name: count, dtype: int64

# %%
(ipl4['team1'].value_counts().sort_index() + ipl4['team2'].value_counts().sort_index()).sort_values(ascending=False).sum()
# Out:
# np.int64(1572)

# %%
786*2 ## Toatal match dono milakar ki kitne khele gye h
# Out:
# 1572

# %%
ipl4.columns
# Out:
# Index(['id', 'city', 'date', 'player_of_match', 'venue', 'neutral_venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'eliminator', 'method', 'umpire1', 'umpire2', 'year',
#        'month'],
#       dtype='object')

# %%
ipl4['winner'].nunique()
# Out:
# 12

# %%
ipl4['winner'].unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Delhi Capitals',
#        'Royal Challengers Bangalore', 'Rajasthan Royals',
#        'Kings XI Punjab', 'Sunrisers Hyderabad', 'Mumbai Indians',
#        'Pune Warriors', 'Kochi Tuskers Kerala', 'Rising Pune Supergiant',
#        'Gujarat Lions'], dtype=object)

# %%
ipl4['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 118
# Chennai Super Kings            103
# Kolkata Knight Riders           97
# Sunrisers Hyderabad             92
# Royal Challengers Bangalore     87
# Delhi Capitals                  82
# Kings XI Punjab                 82
# Rajasthan Royals                79
# Rising Pune Supergiant          15
# Gujarat Lions                   13
# Pune Warriors                   12
# Kochi Tuskers Kerala             6
# Name: count, dtype: int64

# %%
ipl4.columns
# Out:
# Index(['id', 'city', 'date', 'player_of_match', 'venue', 'neutral_venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'eliminator', 'method', 'umpire1', 'umpire2', 'year',
#        'month'],
#       dtype='object')

# %%
ipl4.groupby('year').first() ## har saal ka phla match
# Out:
#            id       city       date  player_of_match  \
# year
# 2008   335982  Bangalore 2008-04-18      BB McCullum
# 2009   392181  Cape Town 2009-04-18     SR Tendulkar
# 2010   419106     Mumbai 2010-03-12       AD Mathews
# 2011   501198    Chennai 2011-04-08       S Anirudha
# 2012   548306    Chennai 2012-04-04          RE Levi
# 2013   597998    Kolkata 2013-04-03        SP Narine
# 2014   729279  Abu Dhabi 2014-04-16        JH Kallis
# 2015   829705    Kolkata 2015-04-08         M Morkel
# 2016   980901     Mumbai 2016-04-09        AM Rahane
# 2017  1082591  Hyderabad 2017-04-05     Yuvraj Singh
# 2018  1136561     Mumbai 2018-04-07         DJ Bravo
# 2019  1175356    Chennai 2019-03-23  Harbhajan Singh
# 2020  1216492  Abu Dhabi 2020-09-19        AT Rayudu
#
#                                           venue  neutral_venue  \
# year
# 2008                      M Chinnaswamy Stadium              0
# 2009                                   Newlands              1
# ...

# %%
ipl4.groupby('year').last() ## har saal ka last match
# Out:
#            id          city       date player_of_match  \
# year
# 2008   336040        Mumbai 2008-06-01       YK Pathan
# 2009   392239  Johannesburg 2009-05-24        A Kumble
# 2010   419165        Mumbai 2010-04-25        SK Raina
# 2011   501271       Chennai 2011-05-28         M Vijay
# 2012   548381       Chennai 2012-05-27        MS Bisla
# 2013   598073       Kolkata 2013-05-26      KA Pollard
# 2014   734049     Bangalore 2014-06-01       MK Pandey
# 2015   829823       Kolkata 2015-05-24       RG Sharma
# 2016   981019     Bangalore 2016-05-29     BCJ Cutting
# 2017  1082650     Hyderabad 2017-05-21       KH Pandya
# 2018  1136620        Mumbai 2018-05-27       SR Watson
# 2019  1181768     Hyderabad 2019-05-12       JJ Bumrah
# 2020  1237181         Dubai 2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# year
# 2008                 Dr DY Patil Sports Academy              0
# ...

# %%
ipl4[ipl4['year'] == 2020]
# Out:
#           id       city       date player_of_match  \
# 756  1216492  Abu Dhabi 2020-09-19       AT Rayudu
# 758  1216494  Abu Dhabi 2020-10-21  Mohammed Siraj
# 759  1216495    Sharjah 2020-11-03        S Nadeem
# 760  1216496    Sharjah 2020-09-22       SV Samson
# 761  1216497  Abu Dhabi 2020-10-24        CV Varun
# 762  1216498      Dubai 2020-10-24       CJ Jordan
# 763  1216499  Abu Dhabi 2020-10-28        SA Yadav
# 764  1216500    Sharjah 2020-10-09        R Ashwin
# 765  1216501  Abu Dhabi 2020-10-07     RA Tripathi
# 766  1216502    Sharjah 2020-10-31  Sandeep Sharma
# 767  1216503  Abu Dhabi 2020-10-01      KA Pollard
# 768  1216504      Dubai 2020-09-30     Shivam Mavi
# 769  1216505  Abu Dhabi 2020-11-02        A Nortje
# 770  1216506  Abu Dhabi 2020-11-01      RD Gaikwad
# 771  1216507      Dubai 2020-10-11       R Tewatia
# 772  1216508  Abu Dhabi 2020-09-23       RG Sharma
# 773  1216509    Sharjah 2020-10-17        S Dhawan
# ...

# %%
ipl4.groupby('year').last()['winner'].value_counts()
# Out:
# winner
# Mumbai Indians           5
# Chennai Super Kings      3
# Sunrisers Hyderabad      2
# Kolkata Knight Riders    2
# Rajasthan Royals         1
# Name: count, dtype: int64

# %%
ipl4.columns
# Out:
# Index(['id', 'city', 'date', 'player_of_match', 'venue', 'neutral_venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'eliminator', 'method', 'umpire1', 'umpire2', 'year',
#        'month'],
#       dtype='object')

# %%
ipl4.groupby(['winner','toss_decision'])
