# %%
import numpy as np
import pandas as pd
print("Module loaded successfully !!!")
# Out:
# Module loaded successfully !!!

# %%
df = pd.read_csv(r"C:\Users\Admin\Desktop\DATA ANYLATICS\Car Details\CAR DETAILS FROM CAR DEKHO.csv")

# %%
df
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner'],
#       dtype='object')

# %%
df.head(10)
# Out:
#                         name  year  selling_price  km_driven    fuel  \
# 0              Maruti 800 AC  2007          60000      70000  Petrol
# 1   Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2       Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3     Datsun RediGO T Option  2017         250000      46000  Petrol
# 4      Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
# 5       Maruti Alto LX BSIII  2007         140000     125000  Petrol
# 6  Hyundai Xcent 1.2 Kappa S  2016         550000      25000  Petrol
# 7   Tata Indigo Grand Petrol  2014         240000      60000  Petrol
# 8   Hyundai Creta 1.6 VTVT S  2015         850000      25000  Petrol
# 9   Maruti Celerio Green VXI  2017         365000      78000     CNG
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# ...

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
df.tail()
# Out:
#                                      name  year  selling_price  km_driven  \
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# 4335  Diesel  Individual       Manual  Second Owner
# 4336  Diesel  Individual       Manual  Second Owner
# 4337  Petrol  Individual       Manual  Second Owner
# 4338  Diesel  Individual       Manual   First Owner
# 4339  Petrol  Individual       Manual   First Owner

# %%
df.tail(3)
# Out:
#                                   name  year  selling_price  km_driven  \
# 4337               Maruti 800 AC BSIII  2009         110000      83000
# 4338  Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                  Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# 4337  Petrol  Individual       Manual  Second Owner
# 4338  Diesel  Individual       Manual   First Owner
# 4339  Petrol  Individual       Manual   First Owner

# %%
df.sample()
# Out:
#                     name  year  selling_price  km_driven    fuel seller_type  \
# 3405  Tata Nano Twist XE  2015         100000      23800  Petrol  Individual
#
#      transmission         owner
# 3405       Manual  Second Owner

# %%
df.sample(2)
# Out:
#                      name  year  selling_price  km_driven    fuel seller_type  \
# 543   Volkswagen Polo GTI  2017         850000      20000  Petrol      Dealer
# 2002    Chevrolet Beat LT  2010         135000      80000  Petrol  Individual
#
#      transmission         owner
# 543     Automatic  Second Owner
# 2002       Manual  Second Owner

# %%
df.describe()
# Out:
#               year  selling_price      km_driven
# count  4340.000000   4.340000e+03    4340.000000
# mean   2013.090783   5.041273e+05   66215.777419
# std       4.215344   5.785487e+05   46644.102194
# min    1992.000000   2.000000e+04       1.000000
# 25%    2011.000000   2.087498e+05   35000.000000
# 50%    2014.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner'],
#       dtype='object')

# %%
df['name']
# Out:
# 0                             Maruti 800 AC
# 1                  Maruti Wagon R LXI Minor
# 2                      Hyundai Verna 1.6 SX
# 3                    Datsun RediGO T Option
# 4                     Honda Amaze VX i-DTEC
#                        ...
# 4335    Hyundai i20 Magna 1.4 CRDi (Diesel)
# 4336             Hyundai i20 Magna 1.4 CRDi
# 4337                    Maruti 800 AC BSIII
# 4338       Hyundai Creta 1.6 CRDi SX Option
# 4339                       Renault KWID RXT
# Name: name, Length: 4340, dtype: object

# %%
df.isnull()
# Out:
#        name   year  selling_price  km_driven   fuel  seller_type  \
# 0     False  False          False      False  False        False
# 1     False  False          False      False  False        False
# 2     False  False          False      False  False        False
# 3     False  False          False      False  False        False
# 4     False  False          False      False  False        False
# ...     ...    ...            ...        ...    ...          ...
# 4335  False  False          False      False  False        False
# 4336  False  False          False      False  False        False
# 4337  False  False          False      False  False        False
# 4338  False  False          False      False  False        False
# 4339  False  False          False      False  False        False
#
#       transmission  owner
# 0            False  False
# 1            False  False
# 2            False  False
# 3            False  False
# 4            False  False
# ...

# %%
df.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# dtype: int64

# %%
df['name']
# Out:
# 0                             Maruti 800 AC
# 1                  Maruti Wagon R LXI Minor
# 2                      Hyundai Verna 1.6 SX
# 3                    Datsun RediGO T Option
# 4                     Honda Amaze VX i-DTEC
#                        ...
# 4335    Hyundai i20 Magna 1.4 CRDi (Diesel)
# 4336             Hyundai i20 Magna 1.4 CRDi
# 4337                    Maruti 800 AC BSIII
# 4338       Hyundai Creta 1.6 CRDi SX Option
# 4339                       Renault KWID RXT
# Name: name, Length: 4340, dtype: object

# %%
df['name'].unique()
# Out:
# array(['Maruti 800 AC', 'Maruti Wagon R LXI Minor',
#        'Hyundai Verna 1.6 SX', ..., 'Mahindra Verito 1.5 D6 BSIII',
#        'Toyota Innova 2.5 VX (Diesel) 8 Seater BS IV',
#        'Hyundai i20 Magna 1.4 CRDi'], shape=(1491,), dtype=object)

# %%
df['name'].value_counts()
# Out:
# name
# Maruti Swift Dzire VDI                     69
# Maruti Alto 800 LXI                        59
# Maruti Alto LXi                            47
# Maruti Alto LX                             35
# Hyundai EON Era Plus                       35
#                                            ..
# Hyundai Verna Transform CRDi VGT SX ABS     1
# Maruti S-Presso VXI Plus                    1
# Toyota Etios Liva 1.2 VX                    1
# Toyota Yaris G                              1
# Hyundai i20 Magna 1.4 CRDi                  1
# Name: count, Length: 1491, dtype: int64

# %%
df['name'].str.upper()
# Out:
# 0                             MARUTI 800 AC
# 1                  MARUTI WAGON R LXI MINOR
# 2                      HYUNDAI VERNA 1.6 SX
# 3                    DATSUN REDIGO T OPTION
# 4                     HONDA AMAZE VX I-DTEC
#                        ...
# 4335    HYUNDAI I20 MAGNA 1.4 CRDI (DIESEL)
# 4336             HYUNDAI I20 MAGNA 1.4 CRDI
# 4337                    MARUTI 800 AC BSIII
# 4338       HYUNDAI CRETA 1.6 CRDI SX OPTION
# 4339                       RENAULT KWID RXT
# Name: name, Length: 4340, dtype: object

# %%
df['name'].str.split(' ')
# Out:
# 0                                [Maruti, 800, AC]
# 1                   [Maruti, Wagon, R, LXI, Minor]
# 2                        [Hyundai, Verna, 1.6, SX]
# 3                      [Datsun, RediGO, T, Option]
# 4                       [Honda, Amaze, VX, i-DTEC]
#                            ...
# 4335    [Hyundai, i20, Magna, 1.4, CRDi, (Diesel)]
# 4336              [Hyundai, i20, Magna, 1.4, CRDi]
# 4337                      [Maruti, 800, AC, BSIII]
# 4338       [Hyundai, Creta, 1.6, CRDi, SX, Option]
# 4339                          [Renault, KWID, RXT]
# Name: name, Length: 4340, dtype: object

# %%
df['name'].str.split(' ')
# Out:
# 0                                [Maruti, 800, AC]
# 1                   [Maruti, Wagon, R, LXI, Minor]
# 2                        [Hyundai, Verna, 1.6, SX]
# 3                      [Datsun, RediGO, T, Option]
# 4                       [Honda, Amaze, VX, i-DTEC]
#                            ...
# 4335    [Hyundai, i20, Magna, 1.4, CRDi, (Diesel)]
# 4336              [Hyundai, i20, Magna, 1.4, CRDi]
# 4337                      [Maruti, 800, AC, BSIII]
# 4338       [Hyundai, Creta, 1.6, CRDi, SX, Option]
# 4339                          [Renault, KWID, RXT]
# Name: name, Length: 4340, dtype: object

# %%
data = "Maruti, 800, AC"
fun = lambda x : x.split(' ')[0]

# %%
fun(data)
# Out:
# 'Maruti,'

# %%
## apply() tab use hota hai jab
# loop likhne ki jagah har value par function chalana ho

# %%
df['name'].apply(lambda x : x.split(' ')[0].upper())
# Out:
# 0        MARUTI
# 1        MARUTI
# 2       HYUNDAI
# 3        DATSUN
# 4         HONDA
#          ...
# 4335    HYUNDAI
# 4336    HYUNDAI
# 4337     MARUTI
# 4338    HYUNDAI
# 4339    RENAULT
# Name: name, Length: 4340, dtype: object

# %%
df['name'].apply(lambda x : x.split(' ')[0].upper()).unique()
# Out:
# array(['MARUTI', 'HYUNDAI', 'DATSUN', 'HONDA', 'TATA', 'CHEVROLET',
#        'TOYOTA', 'JAGUAR', 'MERCEDES-BENZ', 'AUDI', 'SKODA', 'JEEP',
#        'BMW', 'MAHINDRA', 'FORD', 'NISSAN', 'RENAULT', 'FIAT',
#        'VOLKSWAGEN', 'VOLVO', 'MITSUBISHI', 'LAND', 'DAEWOO', 'MG',
#        'FORCE', 'ISUZU', 'OPELCORSA', 'AMBASSADOR', 'KIA'], dtype=object)

# %%
df['Brand Name'] = df['name'].apply(lambda x : x.split(' ')[0])

# %%
df
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner Brand Name
# ...

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner Brand Name
# 0  Individual       Manual   First Owner     Maruti
# 1  Individual       Manual   First Owner     Maruti
# 2  Individual       Manual   First Owner    Hyundai
# 3  Individual       Manual   First Owner     Datsun
# 4  Individual       Manual  Second Owner      Honda

# %%
df.tail()
# Out:
#                                      name  year  selling_price  km_driven  \
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner Brand Name
# 4335  Diesel  Individual       Manual  Second Owner    Hyundai
# 4336  Diesel  Individual       Manual  Second Owner    Hyundai
# 4337  Petrol  Individual       Manual  Second Owner     Maruti
# 4338  Diesel  Individual       Manual   First Owner    Hyundai
# 4339  Petrol  Individual       Manual   First Owner    Renault

# %%
df.sample()
# Out:
#                       name  year  selling_price  km_driven    fuel  \
# 2717  Hyundai Getz 1.3 GLS  2008         110000     110000  Petrol
#
#      seller_type transmission         owner Brand Name
# 2717  Individual       Manual  Second Owner    Hyundai

# %%
df['Brand Name'].nunique()
# Out:
# 29

# %%
df['Brand Name'].value_counts()
# Out:
# Brand Name
# Maruti           1280
# Hyundai           821
# Mahindra          365
# Tata              361
# Honda             252
# Ford              238
# Toyota            206
# Chevrolet         188
# Renault           146
# Volkswagen        107
# Skoda              68
# Nissan             64
# Audi               60
# BMW                39
# Fiat               37
# Datsun             37
# Mercedes-Benz      35
# Jaguar              6
# Mitsubishi          6
# Land                5
# Volvo               4
# Ambassador          4
# Jeep                3
# MG                  2
# OpelCorsa           2
# Daewoo              1
# Force               1
# Isuzu               1
# Kia                 1
# Name: count, dtype: int64

# %%
df['Brand Name'].value_counts().head()
# Out:
# Brand Name
# Maruti      1280
# Hyundai      821
# Mahindra     365
# Tata         361
# Honda        252
# Name: count, dtype: int64

# %%
df['Brand Name'].value_counts().tail()
# Out:
# Brand Name
# OpelCorsa    2
# Daewoo       1
# Force        1
# Isuzu        1
# Kia          1
# Name: count, dtype: int64

# %%
df['Brand Name'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Brand Name'>

# %%
df['Brand Name'].value_counts().plot(kind="line")
# Out:
# <Axes: xlabel='Brand Name'>

# %%
df['Brand Name'].value_counts().head()
# Out:
# Brand Name
# Maruti      1280
# Hyundai      821
# Mahindra     365
# Tata         361
# Honda        252
# Name: count, dtype: int64

# %%
df['Brand Name'].value_counts().head().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
df['Brand Name'].value_counts().head().plot(kind='bar')
# Out:
# <Axes: xlabel='Brand Name'>

# %%
import seaborn as sns

# %%
df['Brand Name'].value_counts().head().plot(kind='bar', color=sns.color_palette("rainbow"))
# Out:
# <Axes: xlabel='Brand Name'>

# %%
df['Brand Name'].value_counts().head().plot(kind='bar',color=sns.color_palette("magma"))
# Out:
# <Axes: xlabel='Brand Name'>

# %%
df['Brand Name'].value_counts().plot(kind='bar',color=sns.color_palette("magma"))
# Out:
# <Axes: xlabel='Brand Name'>

# %%
df
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner Brand Name
# ...

# %%
# value_counts()
# Column me jo bhi values hain,
# wo kitni baar repeat hui hain, wo count karta hai.
df['year'].value_counts()
# Out:
# year
# 2017    466
# 2015    421
# 2012    415
# 2013    386
# 2014    367
# 2018    366
# 2016    357
# 2011    271
# 2010    234
# 2019    195
# 2009    193
# 2008    145
# 2007    134
# 2006    110
# 2005     85
# 2020     48
# 2004     42
# 2003     23
# 2002     21
# 2001     20
# 1998     12
# 2000     12
# 1999     10
# 1997      3
# 1996      2
# 1995      1
# 1992      1
# Name: count, dtype: int64

# %%
df['year'].nunique()
# Out:
# 27

# %%
len(df['year'].value_counts())
# Out:
# 27

# %%
df['year'].value_counts().plot(kind="bar",color=sns.color_palette("magma"))
# Out:
# <Axes: xlabel='year'>

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'Brand Name'],
#       dtype='object')

# %%
df['selling_price'].value_counts()
# Out:
# selling_price
# 300000     162
# 250000     125
# 350000     122
# 550000     107
# 600000     103
#           ...
# 2100000      1
# 828999       1
# 1119000      1
# 746000       1
# 865000       1
# Name: count, Length: 445, dtype: int64

# %%
df['selling_price'].nunique()
# Out:
# 445

# %%
df['selling_price'].value_counts().head().plot(kind='bar',color=sns.color_palette("magma"))
# Out:
# <Axes: xlabel='selling_price'>

# %%
df['selling_price'].value_counts()
# Out:
# selling_price
# 300000     162
# 250000     125
# 350000     122
# 550000     107
# 600000     103
#           ...
# 2100000      1
# 828999       1
# 1119000      1
# 746000       1
# 865000       1
# Name: count, Length: 445, dtype: int64

# %%
df['selling_price'].sort_values()
# Out:
# 2662      20000
# 2495      22000
# 2444      30000
# 3206      35000
# 2849      35000
#          ...
# 1023    4950000
# 2239    4950000
# 3969    5500000
# 89      8150000
# 3872    8900000
# Name: selling_price, Length: 4340, dtype: int64

# %%
df['selling_price'].sort_values(ascending=False)
# Out:
# 3872    8900000
# 89      8150000
# 3969    5500000
# 2258    4950000
# 612     4950000
#          ...
# 2849      35000
# 1832      35000
# 2444      30000
# 2495      22000
# 2662      20000
# Name: selling_price, Length: 4340, dtype: int64

# %%
df['selling_price'].sort_values(ascending=False).head(10)
# Out:
# 3872    8900000
# 89      8150000
# 3969    5500000
# 2258    4950000
# 612     4950000
# 1836    4950000
# 555     4950000
# 2739    4950000
# 1023    4950000
# 900     4950000
# Name: selling_price, dtype: int64

# %%
df['selling_price'].sort_values(ascending=False).tail(10)
# Out:
# 877     40000
# 1350    40000
# 3215    40000
# 4290    37500
# 3206    35000
# 2849    35000
# 1832    35000
# 2444    30000
# 2495    22000
# 2662    20000
# Name: selling_price, dtype: int64

# %%
df['selling_price'].sort_values(ascending=False).tail(10).plot(kind="bar",color=sns.color_palette("cool"))
# Out:
# <Axes: >

# %%
df['selling_price'].sort_values(ascending=False).tail(10).plot(kind="pie",color=sns.color_palette("cool"))
# Out:
# <Axes: ylabel='selling_price'>

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'Brand Name'],
#       dtype='object')

# %%
df['fuel']
# Out:
# 0       Petrol
# 1       Petrol
# 2       Diesel
# 3       Petrol
# 4       Diesel
#          ...
# 4335    Diesel
# 4336    Diesel
# 4337    Petrol
# 4338    Diesel
# 4339    Petrol
# Name: fuel, Length: 4340, dtype: object

# %%
df['fuel'].value_counts()
# Out:
# fuel
# Diesel      2153
# Petrol      2123
# CNG           40
# LPG           23
# Electric       1
# Name: count, dtype: int64

# %%
df['fuel'].value_counts().plot(kind='bar',color=sns.color_palette("magma"))
# Out:
# <Axes: xlabel='fuel'>

# %%
df['fuel'].value_counts().head().plot(kind='bar',color=sns.color_palette("magma"))
# Out:
# <Axes: xlabel='fuel'>

# %%
df['fuel'].value_counts().head().plot(kind='pie',color=sns.color_palette("magma"))
# Out:
# <Axes: ylabel='count'>

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'Brand Name'],
#       dtype='object')

# %%
df['seller_type']
# Out:
# 0       Individual
# 1       Individual
# 2       Individual
# 3       Individual
# 4       Individual
#            ...
# 4335    Individual
# 4336    Individual
# 4337    Individual
# 4338    Individual
# 4339    Individual
# Name: seller_type, Length: 4340, dtype: object

# %%
df['seller_type'].value_counts()
# Out:
# seller_type
# Individual          3244
# Dealer               994
# Trustmark Dealer     102
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'Brand Name'],
#       dtype='object')

# %%
df['transmission']
# Out:
# 0       Manual
# 1       Manual
# 2       Manual
# 3       Manual
# 4       Manual
#          ...
# 4335    Manual
# 4336    Manual
# 4337    Manual
# 4338    Manual
# 4339    Manual
# Name: transmission, Length: 4340, dtype: object

# %%
df['transmission'].value_counts()
# Out:
# transmission
# Manual       3892
# Automatic     448
# Name: count, dtype: int64

# %%
df['transmission'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'Brand Name'],
#       dtype='object')

# %%
df['owner']
# Out:
# 0        First Owner
# 1        First Owner
# 2        First Owner
# 3        First Owner
# 4       Second Owner
#             ...
# 4335    Second Owner
# 4336    Second Owner
# 4337    Second Owner
# 4338     First Owner
# 4339     First Owner
# Name: owner, Length: 4340, dtype: object

# %%
df['owner'].value_counts()
# Out:
# owner
# First Owner             2832
# Second Owner            1106
# Third Owner              304
# Fourth & Above Owner      81
# Test Drive Car            17
# Name: count, dtype: int64

# %%
df['owner'].value_counts().plot(kind='bar',color=sns.color_palette('magma'))
# Out:
# <Axes: xlabel='owner'>

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'Brand Name'],
#       dtype='object')

# %%
df['km_driven']
# Out:
# 0        70000
# 1        50000
# 2       100000
# 3        46000
# 4       141000
#          ...
# 4335     80000
# 4336     80000
# 4337     83000
# 4338     90000
# 4339     40000
# Name: km_driven, Length: 4340, dtype: int64

# %%
df['km_driven'].value_counts()
# Out:
# km_driven
# 70000     236
# 80000     228
# 50000     222
# 120000    220
# 60000     215
#          ...
# 19107       1
# 32077       1
# 6480        1
# 118400      1
# 112198      1
# Name: count, Length: 770, dtype: int64

# %%
df['km_driven'].value_counts().head(20).plot(kind="bar",color=sns.color_palette('rainbow'))
# Out:
# <Axes: xlabel='km_driven'>

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'Brand Name'],
#       dtype='object')

# %%
df['seller_type'].min()
# Out:
# 'Dealer'

# %%
df['seller_type'].max()
# Out:
# 'Trustmark Dealer'

# %%
df['seller_type'] == df['seller_type'].min()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4335    False
# 4336    False
# 4337    False
# 4338    False
# 4339    False
# Name: seller_type, Length: 4340, dtype: bool

# %%
df[df['seller_type'] == df['seller_type'].min()]
# Out:
#                                     name  year  selling_price  km_driven  \
# 12       Toyota Corolla Altis 1.8 VL CVT  2018        1650000      25000
# 25       Toyota Corolla Altis 1.8 VL CVT  2018        1650000      25000
# 26                  Maruti Ciaz VXi Plus  2015         585000      24000
# 27           Hyundai Venue SX Opt Diesel  2019        1195000       5000
# 29            Jaguar XF 2.2 Litre Luxury  2014        1964999      28000
# ...                                  ...   ...            ...        ...
# 4304  Audi Q5 3.0 TDI Quattro Technology  2018        3899000      22000
# 4306              Hyundai i10 Sportz 1.2  2011         235000      43100
# 4309                    Datsun GO Plus T  2017         350000      10171
# 4310     Renault Duster 110PS Diesel RxL  2015         465000      41123
# 4311             Toyota Camry Hybrid 2.5  2017        1900000      20118
#
#         fuel seller_type transmission        owner Brand Name
# ...

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'Brand Name'],
#       dtype='object')

# %%
df['selling_price'].min()
# Out:
# 20000

# %%
df['selling_price'].max()
# Out:
# 8900000

# %%
df['selling_price'] == df['selling_price'].min()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4335    False
# 4336    False
# 4337    False
# 4338    False
# 4339    False
# Name: selling_price, Length: 4340, dtype: bool

# %%
df[df['selling_price'] == df['selling_price'].min()]
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 2662  Ford Ikon 1.6 ZXI NXt  2005          20000      25000  Petrol
#
#      seller_type transmission         owner Brand Name
# 2662  Individual       Manual  Second Owner       Ford

# %%
df[df['selling_price'] == df['selling_price'].max()]
# Out:
#                                           name  year  selling_price  \
# 3872  Audi RS7 2015-2019 Sportback Performance  2016        8900000
#
#       km_driven    fuel seller_type transmission        owner Brand Name
# 3872      13000  Petrol      Dealer    Automatic  First Owner       Audi

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'Brand Name'],
#       dtype='object')

# %%
df['fuel']
# Out:
# 0       Petrol
# 1       Petrol
# 2       Diesel
# 3       Petrol
# 4       Diesel
#          ...
# 4335    Diesel
# 4336    Diesel
# 4337    Petrol
# 4338    Diesel
# 4339    Petrol
# Name: fuel, Length: 4340, dtype: object

# %%
df['fuel'] == 'Petrol'
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 4335    False
# 4336    False
# 4337     True
# 4338    False
# 4339     True
# Name: fuel, Length: 4340, dtype: bool

# %%
p_df = df[df['fuel'] == 'Petrol']

# %%
p_df
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0                    Maruti 800 AC  2007          60000      70000  Petrol
# 1         Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 3           Datsun RediGO T Option  2017         250000      46000  Petrol
# 5             Maruti Alto LX BSIII  2007         140000     125000  Petrol
# 6        Hyundai Xcent 1.2 Kappa S  2016         550000      25000  Petrol
# ...                            ...   ...            ...        ...     ...
# 4326            Honda City 1.5 GXI  2005          65000     150000  Petrol
# 4327                  Tata Nano XM  2015         190000      60000  Petrol
# 4329  Tata Manza Aura Safire BS IV  2010         160000      60000  Petrol
# 4337           Maruti 800 AC BSIII  2009         110000      83000  Petrol
# 4339              Renault KWID RXT  2016         225000      40000  Petrol
#
#      seller_type transmission         owner Brand Name
# ...

# %%
p_df['selling_price']
# Out:
# 0        60000
# 1       135000
# 3       250000
# 5       140000
# 6       550000
#          ...
# 4326     65000
# 4327    190000
# 4329    160000
# 4337    110000
# 4339    225000
# Name: selling_price, Length: 2123, dtype: int64

# %%
p_df['selling_price'].min()
# Out:
# 20000

# %%
p_df['selling_price'] == p_df['selling_price'].max()
# Out:
# 0       False
# 1       False
# 3       False
# 5       False
# 6       False
#         ...
# 4326    False
# 4327    False
# 4329    False
# 4337    False
# 4339    False
# Name: selling_price, Length: 2123, dtype: bool

# %%
p_df[p_df['selling_price'] == p_df['selling_price'].max()]
# Out:
#                                           name  year  selling_price  \
# 3872  Audi RS7 2015-2019 Sportback Performance  2016        8900000
#
#       km_driven    fuel seller_type transmission        owner Brand Name
# 3872      13000  Petrol      Dealer    Automatic  First Owner       Audi

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'Brand Name'],
#       dtype='object')

# %%
df['fuel'] == "Desel"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4335    False
# 4336    False
# 4337    False
# 4338    False
# 4339    False
# Name: fuel, Length: 4340, dtype: bool

# %%
df['fuel'] == "Desel"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4335    False
# 4336    False
# 4337    False
# 4338    False
# 4339    False
# Name: fuel, Length: 4340, dtype: bool

# %%
df[df['fuel'] == "Desel"]
# Out:
# Empty DataFrame
# Columns: [name, year, selling_price, km_driven, fuel, seller_type, transmission, owner, Brand Name]
# Index: []

# %%
d_pf = df[df['fuel'] == "Desel"]

# %%
p_df
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0                    Maruti 800 AC  2007          60000      70000  Petrol
# 1         Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 3           Datsun RediGO T Option  2017         250000      46000  Petrol
# 5             Maruti Alto LX BSIII  2007         140000     125000  Petrol
# 6        Hyundai Xcent 1.2 Kappa S  2016         550000      25000  Petrol
# ...                            ...   ...            ...        ...     ...
# 4326            Honda City 1.5 GXI  2005          65000     150000  Petrol
# 4327                  Tata Nano XM  2015         190000      60000  Petrol
# 4329  Tata Manza Aura Safire BS IV  2010         160000      60000  Petrol
# 4337           Maruti 800 AC BSIII  2009         110000      83000  Petrol
# 4339              Renault KWID RXT  2016         225000      40000  Petrol
#
#      seller_type transmission         owner Brand Name
# ...

# %%
p_df['selling_price'].min()
# Out:
# 20000

# %%
p_df['selling_price'] == p_df['selling_price'].min()
# Out:
# 0       False
# 1       False
# 3       False
# 5       False
# 6       False
#         ...
# 4326    False
# 4327    False
# 4329    False
# 4337    False
# 4339    False
# Name: selling_price, Length: 2123, dtype: bool

# %%
p_df[p_df['selling_price'] == p_df['selling_price'].min()]
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 2662  Ford Ikon 1.6 ZXI NXt  2005          20000      25000  Petrol
#
#      seller_type transmission         owner Brand Name
# 2662  Individual       Manual  Second Owner       Ford

# %%
p_df[p_df['selling_price'] == p_df['selling_price'].max()]
# Out:
#                                           name  year  selling_price  \
# 3872  Audi RS7 2015-2019 Sportback Performance  2016        8900000
#
#       km_driven    fuel seller_type transmission        owner Brand Name
# 3872      13000  Petrol      Dealer    Automatic  First Owner       Audi

# %%
(df['owner'] == 'Second Owner')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 4335     True
# 4336     True
# 4337     True
# 4338    False
# 4339    False
# Name: owner, Length: 4340, dtype: bool

# %%
(df['owner'] == 'Second Owner') & (df['fuel'] == 'Desel') & (df['Brand Name'] == 'Audi')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4335    False
# 4336    False
# 4337    False
# 4338    False
# 4339    False
# Length: 4340, dtype: bool

# %%
(df['owner'] == 'Second Owner') & (df['fuel'] == 'Desel') & (df['Brand Name'] == 'Audi') & (df['selling_price'] <=2500000)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4335    False
# 4336    False
# 4337    False
# 4338    False
# 4339    False
# Length: 4340, dtype: bool

# %%
df[(df['owner'] == 'Second Owner') & (df['fuel'] == 'Desel') & (df['Brand Name'] == 'Audi') & (df['selling_price'] <=250000)]
# Out:
# Empty DataFrame
# Columns: [name, year, selling_price, km_driven, fuel, seller_type, transmission, owner, Brand Name]
# Index: []

# %%
df[(df['owner'] == 'Second Owner') & (df['fuel'] == 'Petrol') & (df['selling_price'] >=450000) & (df['Brand Name'] == "Maruti")]
# Out:
#                              name  year  selling_price  km_driven    fuel  \
# 545   Maruti Celerio VXI AMT BSIV  2016         450000      39415  Petrol
# 2184  Maruti Celerio VXI AMT BSIV  2016         450000      39415  Petrol
# 3663          Maruti Alto 800 LXI  2013         900000      60000  Petrol
# 3748       Maruti Swift Dzire ZXI  2015         615000     110000  Petrol
# 3989             Maruti Swift VXI  2013         475000      60000  Petrol
#
#            seller_type transmission         owner Brand Name
# 545   Trustmark Dealer    Automatic  Second Owner     Maruti
# 2184  Trustmark Dealer    Automatic  Second Owner     Maruti
# 3663        Individual       Manual  Second Owner     Maruti
# 3748        Individual       Manual  Second Owner     Maruti
# 3989        Individual       Manual  Second Owner     Maruti

# %%
df
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner Brand Name
# ...

# %% [markdown]
# # Group by
# - Jab hume data ko kisi column ke basis par groups me todna ho
# - Aur fir har group par calculation (sum, mean, count, etc.) karna ho

# %%
# textual pe group chalgea
# numerical pe aggeression chalega

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'Brand Name'],
#       dtype='object')

# %%
df.groupby('fuel')

# %%
type(df.groupby('fuel'))
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
group_data = df.groupby('fuel')

# %%
for i in group_data:
    print(i)
# Out:
# ('CNG',                                         name  year  selling_price  km_driven  \
# 9                   Maruti Celerio Green VXI  2017         365000      78000
# 22                  Maruti Celerio Green VXI  2017         365000      78000
# 176                  Maruti Alto K10 LXI CNG  2020         282000      40000
# 351              Tata Indigo CS Emax CNG GLX  2014         185000      72000
# 352   Maruti Eeco 5 STR With AC Plus HTR CNG  2012         229999      75000
# 361              Hyundai Santro Xing GLS CNG  2010         130000      98000
# 664          Hyundai Santro Xing GL PLUS CNG  2007          90000      80000
# 712                    Maruti Ertiga VXI CNG  2013         525000      56228
# 824                  Maruti Alto 800 CNG LXI  2012         170000      97000
# 863                   Hyundai Accent GLE CNG  2009         160000      70000
# 1138                  Maruti Wagon R LXI CNG  2013         250000      71000
# ...

# %%
df.shape
# Out:
# (4340, 9)

# %%
list(group_data)[0]
# Out:
# ('CNG',
#                                          name  year  selling_price  km_driven  \
#  9                   Maruti Celerio Green VXI  2017         365000      78000
#  22                  Maruti Celerio Green VXI  2017         365000      78000
#  176                  Maruti Alto K10 LXI CNG  2020         282000      40000
#  351              Tata Indigo CS Emax CNG GLX  2014         185000      72000
#  352   Maruti Eeco 5 STR With AC Plus HTR CNG  2012         229999      75000
#  361              Hyundai Santro Xing GLS CNG  2010         130000      98000
#  664          Hyundai Santro Xing GL PLUS CNG  2007          90000      80000
#  712                    Maruti Ertiga VXI CNG  2013         525000      56228
#  824                  Maruti Alto 800 CNG LXI  2012         170000      97000
#  863                   Hyundai Accent GLE CNG  2009         160000      70000
#  1138                  Maruti Wagon R LXI CNG  2013         250000      71000
# ...

# %%
group_data.first()
# Out:
#                               name  year  selling_price  km_driven  \
# fuel
# CNG       Maruti Celerio Green VXI  2017         365000      78000
# Diesel        Hyundai Verna 1.6 SX  2012         600000     100000
# Electric       Toyota Camry Hybrid  2006         310000      62000
# LPG         Maruti Wagon R DUO LPG  2014         210000      90000
# Petrol               Maruti 800 AC  2007          60000      70000
#
#          seller_type transmission         owner Brand Name
# fuel
# CNG       Individual       Manual   First Owner     Maruti
# Diesel    Individual       Manual   First Owner    Hyundai
# Electric      Dealer    Automatic  Second Owner     Toyota
# LPG       Individual       Manual   First Owner     Maruti
# Petrol    Individual       Manual   First Owner     Maruti

# %%
group_data.get_group('CNG')
# Out:
#                                         name  year  selling_price  km_driven  \
# 9                   Maruti Celerio Green VXI  2017         365000      78000
# 22                  Maruti Celerio Green VXI  2017         365000      78000
# 176                  Maruti Alto K10 LXI CNG  2020         282000      40000
# 351              Tata Indigo CS Emax CNG GLX  2014         185000      72000
# 352   Maruti Eeco 5 STR With AC Plus HTR CNG  2012         229999      75000
# 361              Hyundai Santro Xing GLS CNG  2010         130000      98000
# 664          Hyundai Santro Xing GL PLUS CNG  2007          90000      80000
# 712                    Maruti Ertiga VXI CNG  2013         525000      56228
# 824                  Maruti Alto 800 CNG LXI  2012         170000      97000
# 863                   Hyundai Accent GLE CNG  2009         160000      70000
# 1138                  Maruti Wagon R LXI CNG  2013         250000      71000
# ...

# %%
group_data.first()
# Out:
#                               name  year  selling_price  km_driven  \
# fuel
# CNG       Maruti Celerio Green VXI  2017         365000      78000
# Diesel        Hyundai Verna 1.6 SX  2012         600000     100000
# Electric       Toyota Camry Hybrid  2006         310000      62000
# LPG         Maruti Wagon R DUO LPG  2014         210000      90000
# Petrol               Maruti 800 AC  2007          60000      70000
#
#          seller_type transmission         owner Brand Name
# fuel
# CNG       Individual       Manual   First Owner     Maruti
# Diesel    Individual       Manual   First Owner    Hyundai
# Electric      Dealer    Automatic  Second Owner     Toyota
# LPG       Individual       Manual   First Owner     Maruti
# Petrol    Individual       Manual   First Owner     Maruti

# %%
group_data.get_group('CNG').head()
# Out:
#                                        name  year  selling_price  km_driven  \
# 9                  Maruti Celerio Green VXI  2017         365000      78000
# 22                 Maruti Celerio Green VXI  2017         365000      78000
# 176                 Maruti Alto K10 LXI CNG  2020         282000      40000
# 351             Tata Indigo CS Emax CNG GLX  2014         185000      72000
# 352  Maruti Eeco 5 STR With AC Plus HTR CNG  2012         229999      75000
#
#     fuel seller_type transmission        owner Brand Name
# 9    CNG  Individual       Manual  First Owner     Maruti
# 22   CNG  Individual       Manual  First Owner     Maruti
# 176  CNG  Individual       Manual  First Owner     Maruti
# 351  CNG      Dealer       Manual  First Owner       Tata
# 352  CNG      Dealer       Manual  First Owner     Maruti

# %%
group_data.head()
# Out:
#                                            name  year  selling_price  \
# 0                                 Maruti 800 AC  2007          60000
# 1                      Maruti Wagon R LXI Minor  2007         135000
# 2                          Hyundai Verna 1.6 SX  2012         600000
# 3                        Datsun RediGO T Option  2017         250000
# 4                         Honda Amaze VX i-DTEC  2014         450000
# 5                          Maruti Alto LX BSIII  2007         140000
# 6                     Hyundai Xcent 1.2 Kappa S  2016         550000
# 9                      Maruti Celerio Green VXI  2017         365000
# 15                         Hyundai Verna 1.6 SX  2012         600000
# 17                        Honda Amaze VX i-DTEC  2014         450000
# 22                     Maruti Celerio Green VXI  2017         365000
# 27                  Hyundai Venue SX Opt Diesel  2019        1195000
# 157                      Maruti Wagon R DUO LPG  2014         210000
# ...

# %%
group_data.head(1)
# Out:
#                           name  year  selling_price  km_driven      fuel  \
# 0                Maruti 800 AC  2007          60000      70000    Petrol
# 2         Hyundai Verna 1.6 SX  2012         600000     100000    Diesel
# 9     Maruti Celerio Green VXI  2017         365000      78000       CNG
# 157     Maruti Wagon R DUO LPG  2014         210000      90000       LPG
# 4145       Toyota Camry Hybrid  2006         310000      62000  Electric
#
#      seller_type transmission         owner Brand Name
# 0     Individual       Manual   First Owner     Maruti
# 2     Individual       Manual   First Owner    Hyundai
# 9     Individual       Manual   First Owner     Maruti
# 157   Individual       Manual   First Owner     Maruti
# 4145      Dealer    Automatic  Second Owner     Toyota

# %%
group_data.tail(1)
# Out:
#                                   name  year  selling_price  km_driven  \
# 3781      Maruti Wagon R LXI DUO BSIII  2007          70000     162000
# 4145               Toyota Camry Hybrid  2006         310000      62000
# 4152      Hyundai Accent Executive CNG  2010         140000     110000
# 4338  Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                  Renault KWID RXT  2016         225000      40000
#
#           fuel seller_type transmission         owner Brand Name
# 3781       LPG  Individual       Manual   First Owner     Maruti
# 4145  Electric      Dealer    Automatic  Second Owner     Toyota
# 4152       CNG  Individual       Manual   First Owner    Hyundai
# 4338    Diesel  Individual       Manual   First Owner    Hyundai
# 4339    Petrol  Individual       Manual   First Owner    Renault

# %%
group_data.tail(2)
# Out:
#                                         name  year  selling_price  km_driven  \
# 3752              Hyundai EON LPG Magna Plus  2015         240000     110000
# 3781            Maruti Wagon R LXI DUO BSIII  2007          70000     162000
# 4140  Maruti Eeco 5 STR With AC Plus HTR CNG  2018         409999      45000
# 4145                     Toyota Camry Hybrid  2006         310000      62000
# 4152            Hyundai Accent Executive CNG  2010         140000     110000
# 4336              Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                     Maruti 800 AC BSIII  2009         110000      83000
# 4338        Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                        Renault KWID RXT  2016         225000      40000
#
#           fuel seller_type transmission         owner Brand Name
# 3752       LPG  Individual       Manual   First Owner    Hyundai
# 3781       LPG  Individual       Manual   First Owner     Maruti
# ...

# %%
group_data['km_driven'].min()
# Out:
# fuel
# CNG          4000
# Diesel          1
# Electric    62000
# LPG         29000
# Petrol        101
# Name: km_driven, dtype: int64

# %%
group_data['km_driven'].max()
# Out:
# fuel
# CNG         120000
# Diesel      560000
# Electric     62000
# LPG         170000
# Petrol      806599
# Name: km_driven, dtype: int64

# %%
group_data['km_driven'].max().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='fuel'>

# %%
group_data['km_driven'].min().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='fuel'>

# %%
group_data['year'].min()
# Out:
# fuel
# CNG         2005
# Diesel      1996
# Electric    2006
# LPG         1998
# Petrol      1992
# Name: year, dtype: int64

# %%
group_data['year'].min().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='fuel'>

# %%
group_data['year'].max().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='fuel'>

# %%
brand_df = df.groupby('Brand Name')

# %%
brand_df

# %%
brand_df['selling_price'].min()
# Out:
# Brand Name
# Ambassador         50000
# Audi              650000
# BMW               480000
# Chevrolet          50000
# Daewoo             60000
# Datsun            200000
# Fiat               55000
# Force             346000
# Ford               20000
# Honda              65000
# Hyundai            48000
# Isuzu            1500000
# Jaguar           1800000
# Jeep             1400000
# Kia              1300000
# Land             2349000
# MG               1825000
# Mahindra           80000
# Maruti             30000
# Mercedes-Benz     350000
# Mitsubishi        525000
# Nissan            138000
# OpelCorsa          35000
# Renault           200000
# Skoda              90000
# Tata               35000
# Toyota             95000
# Volkswagen        130000
# Volvo            1750000
# Name: selling_price, dtype: int64

# %%
brand_df['selling_price'].min().sort_values()
# Out:
# Brand Name
# Ford               20000
# Maruti             30000
# OpelCorsa          35000
# Tata               35000
# Hyundai            48000
# Ambassador         50000
# Chevrolet          50000
# Fiat               55000
# Daewoo             60000
# Honda              65000
# Mahindra           80000
# Skoda              90000
# Toyota             95000
# Volkswagen        130000
# Nissan            138000
# Renault           200000
# Datsun            200000
# Force             346000
# Mercedes-Benz     350000
# BMW               480000
# Mitsubishi        525000
# Audi              650000
# Kia              1300000
# Jeep             1400000
# Isuzu            1500000
# Volvo            1750000
# Jaguar           1800000
# MG               1825000
# Land             2349000
# Name: selling_price, dtype: int64

# %%
brand_df['selling_price'].min().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Brand Name'>

# %%
brand_df['selling_price'].max().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Brand Name'>

# %%
brand_df['selling_price'].max().sort_values().plot(kind='bar',color=sns.color_palette('magma'))
# Out:
# <Axes: xlabel='Brand Name'>

# %%
df.sample()
# Out:
#                                    name  year  selling_price  km_driven  \
# 2941  Volkswagen Polo 1.0 MPI Trendline  2012         271000      49000
#
#         fuel seller_type transmission        owner  Brand Name
# 2941  Petrol      Dealer       Manual  First Owner  Volkswagen

# %%
brand_df['selling_price'].mean()
# Out:
# Brand Name
# Ambassador       1.800000e+05
# Audi             1.931633e+06
# BMW              2.945385e+06
# Chevrolet        2.367271e+05
# Daewoo           6.000000e+04
# Datsun           2.970269e+05
# Fiat             2.834324e+05
# Force            3.460000e+05
# Ford             5.712731e+05
# Honda            5.381468e+05
# Hyundai          4.199403e+05
# Isuzu            1.500000e+06
# Jaguar           2.069166e+06
# Jeep             1.530000e+06
# Kia              1.300000e+06
# Land             3.609800e+06
# MG               1.842500e+06
# Mahindra         5.877095e+05
# Maruti           3.424163e+05
# Mercedes-Benz    2.776657e+06
# Mitsubishi       8.400000e+05
# Nissan           4.499375e+05
# OpelCorsa        8.850000e+04
# Renault          4.193767e+05
# Skoda            4.900147e+05
# Tata             2.840834e+05
# Toyota           9.243592e+05
# Volkswagen       4.710373e+05
# Volvo            2.556250e+06
# Name: selling_price, dtype: float64

# %%
pd.options.display.float_format  = '{:,.0f}'.format

# %%
brand_df['selling_price'].mean()
# Out:
# Brand Name
# Ambassador        180,000
# Audi            1,931,633
# BMW             2,945,385
# Chevrolet         236,727
# Daewoo             60,000
# Datsun            297,027
# Fiat              283,432
# Force             346,000
# Ford              571,273
# Honda             538,147
# Hyundai           419,940
# Isuzu           1,500,000
# Jaguar          2,069,166
# Jeep            1,530,000
# Kia             1,300,000
# Land            3,609,800
# MG              1,842,500
# Mahindra          587,710
# Maruti            342,416
# Mercedes-Benz   2,776,657
# Mitsubishi        840,000
# Nissan            449,937
# OpelCorsa          88,500
# Renault           419,377
# Skoda             490,015
# Tata              284,083
# Toyota            924,359
# Volkswagen        471,037
# Volvo           2,556,250
# Name: selling_price, dtype: float64

# %%
brand_df['selling_price'].mean().sort_values()
# Out:
# Brand Name
# Daewoo             60,000
# OpelCorsa          88,500
# Ambassador        180,000
# Chevrolet         236,727
# Fiat              283,432
# Tata              284,083
# Datsun            297,027
# Maruti            342,416
# Force             346,000
# Renault           419,377
# Hyundai           419,940
# Nissan            449,937
# Volkswagen        471,037
# Skoda             490,015
# Honda             538,147
# Ford              571,273
# Mahindra          587,710
# Mitsubishi        840,000
# Toyota            924,359
# Kia             1,300,000
# Isuzu           1,500,000
# Jeep            1,530,000
# MG              1,842,500
# Audi            1,931,633
# Jaguar          2,069,166
# Volvo           2,556,250
# Mercedes-Benz   2,776,657
# BMW             2,945,385
# Land            3,609,800
# Name: selling_price, dtype: float64

# %%
df[df['Brand Name'] == 'Audi']['selling_price'].describe()
# Out:
# count          60
# mean    1,931,633
# std     1,236,250
# min       650,000
# 25%     1,300,000
# 50%     1,580,000
# 75%     1,850,000
# max     8,900,000
# Name: selling_price, dtype: float64

# %%
def car_details(brand):
    brand = brand.title()
    return df[df['Brand Name'] == brand]['selling_price'].describe()

# %%
car_details('maruti')
# Out:
# count       1,280
# mean      342,416
# std       230,846
# min        30,000
# 25%       150,000
# 50%       280,500
# 75%       500,000
# max     1,100,000
# Name: selling_price, dtype: float64

# %%
car_details('honda')
# Out:
# count         252
# mean      538,147
# std       278,700
# min        65,000
# 25%       325,000
# 50%       495,000
# 75%       700,000
# max     1,800,000
# Name: selling_price, dtype: float64

# %%
group_df = df.groupby(['Brand Name','fuel'])

# %%
group_df['selling_price'].min()
# Out:
# Brand Name     fuel
# Ambassador     Diesel        50000
#                Petrol       430000
# Audi           Diesel       850000
#                Petrol       650000
# BMW            Diesel       700000
#                Petrol       480000
# Chevrolet      CNG          229999
#                Diesel        95000
#                LPG          200000
#                Petrol        50000
# Daewoo         Petrol        60000
# Datsun         Petrol       200000
# Fiat           Diesel        55000
#                Petrol        80000
# Force          Diesel       346000
# Ford           Diesel        80000
#                Petrol        20000
# Honda          Diesel       290000
#                Petrol        65000
# Hyundai        CNG           90000
#                Diesel        85000
#                LPG          170000
#                Petrol        48000
# Isuzu          Diesel      1500000
# Jaguar         Diesel      1800000
#                Petrol      2050000
# ...

# %%
group_df['selling_price'].min().sort_values()
# Out:
# Brand Name     fuel
# Ford           Petrol        20000
# Maruti         Petrol        30000
# OpelCorsa      Petrol        35000
# Tata           Petrol        35000
#                Diesel        45000
# Maruti         CNG           45000
# Hyundai        Petrol        48000
# Maruti         LPG           50000
# Chevrolet      Petrol        50000
# Ambassador     Diesel        50000
# Fiat           Diesel        55000
# Daewoo         Petrol        60000
# Honda          Petrol        65000
# Maruti         Diesel        75000
# Fiat           Petrol        80000
# Ford           Diesel        80000
# Mahindra       Petrol        80000
#                Diesel        80000
# Hyundai        Diesel        85000
# Skoda          Diesel        90000
# Hyundai        CNG           90000
# Toyota         Petrol        95000
# Chevrolet      Diesel        95000
# Volkswagen     Diesel       130000
# Nissan         Diesel       138000
# Toyota         Diesel       150000
# ...
