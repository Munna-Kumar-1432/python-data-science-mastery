# %%
import matplotlib

# %%
print(dir(matplotlib))
# Out:
# ['ExecutableNotFoundError', 'MatplotlibDeprecationWarning', 'MutableMapping', 'Parameter', 'Path', 'RcParams', '_ExecInfo', '_VersionInfo', '__all__', '__bibtex__', '__builtins__', '__cached__', '__doc__', '__file__', '__getattr__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '_add_data_doc', '_api', '_c_internal_utils', '_check_versions', '_cm', '_cm_bivar', '_cm_listed', '_cm_multivar', '_color_data', '_deprecated_ignore_map', '_deprecated_map', '_deprecated_remain_as_none', '_docstring', '_ensure_handler', '_enums', '_fontconfig_pattern', '_get_config_or_cache_dir', '_get_executable_info', '_get_ssl_context', '_get_version', '_get_xdg_cache_dir', '_get_xdg_config_dir', '_image', '_init_tests', '_label_from_arg', '_log', '_logged_cached', '_open_file_or_url', '_parse_to_version_info', '_path', '_preprocess_data', '_rc_params_in_file', '_replacer', '_val_or_rc', '_version', 'artist', 'atexit', 'backends', 'bezier', 'bivar_colormaps', 'cbook', 'cm', 'color_sequen
# ...

# %%
import matplotlib.pyplot as plt
print(dir(plt))
# Out:
# ['AbstractContextManager', 'Annotation', 'Arrow', 'Artist', 'AutoLocator', 'AxLine', 'Axes', 'BackendFilter', 'Button', 'Circle', 'Colorizer', 'ColorizingArtist', 'Colormap', 'Enum', 'ExitStack', 'Figure', 'FigureBase', 'FigureCanvasBase', 'FigureManagerBase', 'FixedFormatter', 'FixedLocator', 'FormatStrFormatter', 'Formatter', 'FuncFormatter', 'GridSpec', 'IndexLocator', 'Line2D', 'LinearLocator', 'Locator', 'LogFormatter', 'LogFormatterExponent', 'LogFormatterMathtext', 'LogLocator', 'MaxNLocator', 'MouseButton', 'MultipleLocator', 'Normalize', 'NullFormatter', 'NullLocator', 'PolarAxes', 'Polygon', 'Rectangle', 'ScalarFormatter', 'Slider', 'Subplot', 'SubplotSpec', 'TYPE_CHECKING', 'Text', 'TickHelper', 'Widget', '_ColorizerInterface', '_NO_PYPLOT_NOTE', '_REPL_DISPLAYHOOK', '_ReplDisplayHook', '__annotations__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_add_pyplot_note', '_api', '_auto_draw_if_interactive', '_backe
# ...

# %%
print(dir(matplotlib.table))
# Out:
# ['Artist', 'Bbox', 'Cell', 'CustomCell', 'Path', 'Rectangle', 'Table', 'Text', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_api', '_docstring', '_is_pandas_dataframe', 'allow_rasterization', 'np', 'table']

# %% [markdown]
# ![handout-beginner.webp](attachment:f1035071-a001-4fab-bc2e-56479ddd49a8.webp)

# %% [markdown]
# ![cheatsheets-2.webp](attachment:c83181c4-de99-4b62-9ec7-9777586191ef.webp)

# %% [markdown]
# ![handout-intermediate.png](attachment:24b5ee5b-b6ad-428e-bd7d-40f83f0e908d.png)

# %% [markdown]
# ![handout-tips.webp](attachment:c1c10506-6fa4-450f-b4f2-3c8832d4175a.webp)

# %%
matplotlib.__version__
# Out:
# '3.10.6'

# %%
import pandas
pandas.__version__
# Out:
# '2.3.3'

# %%
import numpy 
numpy.__version__
# Out:
# '2.3.5'

# %% [markdown]
# ![sphx_glr_anatomy_001_2_00x.webp](attachment:a53ad5c1-2927-4748-8b09-4fb158873a79.webp)

# %% [markdown]
# # LINE PLOT

# %%
x = list('abcde'.upper())

# %%
x
# Out:
# ['A', 'B', 'C', 'D', 'E']

# %%
import numpy as np
import pandas as pd
y = np.random.randint(1,100,5)

# %%
y
# Out:
# array([49, 29, 58, 16, 38], dtype=int32)

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(x,y)

# %%
# meta information not showing

# %%
plt.plot(x,y)
plt.show()

# %%
# Increase or Decrease grapgh size  : plt.figure(figsize=(9,8))

# %%
plt.figure(figsize=(5,3))
plt.plot(x,y)
plt.show()

# %%
# Represent X and Y : xlabel and ylabel

# %%
plt.figure(figsize=(4,4))
plt.plot(x,y)
plt.xlabel("Class")
plt.ylabel("Avg Marks")
plt.show()

# %%
# Increase or Decrease Fontsize and also change color

# %%
plt.figure(figsize=(5,5))
plt.plot(x,y)
plt.xlabel("Class",fontsize=30,fontstyle='italic')
plt.ylabel("Avg Marks",fontsize=20,fontstyle='italic')
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.plot(x,y)
plt.xlabel("Class",fontsize=30,fontstyle='italic',color='r')
plt.ylabel("Avg Marks",fontsize=20,fontstyle='italic')
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.plot(x,y)
plt.xlabel("Class",fontsize=30,fontstyle='italic',color='r')
plt.ylabel("Avg Marks",{'fontsize':20,'fontstyle':'italic','color':'g'})
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(x,y,linestyle="--")
plt.xlabel("Class",fontsize=30,color='r')
plt.ylabel("Avg Marks",fontsize=20)

plt.title("My ScoreCard",color="green",fontsize=20)

plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(x,y,linestyle="--")
plt.xlabel("Class",fontsize=30,color='r')
plt.ylabel("Avg Marks",fontsize=20)

plt.title("My ScoreCard".upper(),color="green",fontsize=20)

plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(x,y,linestyle="--")
plt.xlabel("Class",fontsize=30,color='r')
plt.ylabel("Avg Marks",fontsize=20)

plt.title("My ScoreCard".upper(),color="green",fontsize=20)
plt.grid()

plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(x,y,linestyle="--",alpha=0.2)
plt.xlabel("Class",fontsize=30,color='r')
plt.ylabel("Avg Marks",fontsize=20)

plt.title("My ScoreCard".upper(),color="green",fontsize=20)
plt.grid(alpha=0.5)

plt.show()

# %%
x = list('abcdef'.upper())
y1 = np.random.randint(1,200,6)
y2 = np.random.randint(1,200,6)

plt.plot(x,y1,linestyle='--',color='r')
plt.plot(x,y2,color='g')

plt.xlabel("Class",fontsize=20, color='r')
plt.ylabel("Avg Marks",fontsize=20,color='g')

plt.grid(alpha=0.5)
plt.show()

# %%
x = list('abcdef'.upper())
y1 = np.random.randint(1,200,6)
y2 = np.random.randint(1,200,6)

plt.plot(x,y1,linestyle='--',color='r')
plt.plot(x,y2,color='g')

plt.xlabel("Class",fontsize=20, color='r')
plt.ylabel("Avg Marks",fontsize=20,color='g')

plt.title("My Score".upper())

plt.grid(alpha=0.5)
plt.show()

# %%
x = list('abcdef'.upper())
y1 = np.random.randint(1,200,6)
y2 = np.random.randint(1,200,6)

plt.plot(x,y1,linestyle='--',color='r',label="Estimated Marks")
plt.plot(x,y2,color='g',label="Actual Marks")

plt.xlabel("Class",fontsize=20, color='r')
plt.ylabel("Avg Marks",fontsize=20,color='g')

plt.legend()

plt.grid(alpha=0.5)
plt.show()

# %%
x = list('abcdef'.upper())
y1 = np.random.randint(1,200,6)
y2 = np.random.randint(1,200,6)

plt.plot(x,y1,linestyle='--',color='r',label="Estimated Marks")
plt.plot(x,y2,color='g',label="Actual Marks")

plt.xlabel("Class",fontsize=20, color='r')
plt.ylabel("Avg Marks",fontsize=20,color='g')

plt.legend(loc=2)

plt.grid(alpha=0.5)
plt.show()

# %%
x = list('abcdef'.upper())
y1 = np.random.randint(1,200,6)
y2 = np.random.randint(1,200,6)

plt.plot(x,y1,linestyle='--',color='r',label="Estimated Marks")
plt.plot(x,y2,color='g',label="Actual Marks")

plt.xlabel("Class",fontsize=20, color='r')
plt.ylabel("Avg Marks",fontsize=20,color='g')

plt.legend(loc=10)

plt.grid(alpha=0.5)
plt.show()

# %%
# Data Points

# %%
x = list('abcdef'.upper())
np.random.seed(1)
y1 = np.random.randint(1,200,6)
y2 = np.random.randint(1,200,6)

plt.plot(x,y1,linestyle='--',color='r',label="Estimated Marks")
plt.plot(x,y2,color='g',label="Actual Marks")

plt.xlabel("Class",fontsize=20, color='r')
plt.ylabel("Avg Marks",fontsize=20,color='g')

plt.legend()

plt.grid(alpha=0.5)

plt.text('A',30,'30')

plt.show()

# %%
x = list('abcdef'.upper())
np.random.seed(1)
y1 = np.random.randint(1,200,6)
y2 = np.random.randint(1,200,6)

plt.plot(x,y1,linestyle='--',color='r',label="Estimated Marks")
plt.plot(x,y2,color='g',label="Actual Marks")

plt.xlabel("Class",fontsize=20, color='r')
plt.ylabel("Avg Marks",fontsize=20,color='g')

plt.legend()

plt.grid(alpha=0.5)

plt.text('A',30,'30')

plt.show()

# %%
x
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F']

# %%
y1
# Out:
# array([ 38, 141,  73, 138, 134,  80], dtype=int32)

# %%
y2
# Out:
# array([193, 145, 130,  72, 135,  26], dtype=int32)

# %%
zip(x,y1)

# %%
for i,j in zip(x,y1):
    print(i,j)
# Out:
# A 38
# B 141
# C 73
# D 138
# E 134
# F 80

# %%
x = list('abcdef'.upper())
np.random.seed(1)
y1 = np.random.randint(1,200,6)
y2 = np.random.randint(1,200,6)

plt.plot(x,y1,linestyle='--',color='r',label="Estimated Marks")
plt.plot(x,y2,color='g',label="Actual Marks")

plt.xlabel("Class",fontsize=20, color='r')
plt.ylabel("Avg Marks",fontsize=20,color='g')

plt.legend()

plt.grid(alpha=0.5)

for i,j in zip(x,y1):
  plt.text(i,j-4,str(j))

for i,j in zip(x,y2):
    plt.text(i,j,str(j))



plt.show()

# %%
x = list('abcdef'.upper())

y1 = np.random.randint(1,200,6)
y2 = np.random.randint(1,200,6)

plt.plot(x,y1,linestyle='--',color='r',label="Estimated Marks")
plt.plot(x,y2,color='g',label="Actual Marks")

plt.xlabel("Class",fontsize=20, color='r')
plt.ylabel("Avg Marks",fontsize=20,color='g')

plt.legend()

plt.grid(alpha=0.5)

for i,j in zip(x,y1):
  plt.text(i,j-4,str(j))

for i,j in zip(x,y2):
    plt.text(i,j,str(j))



plt.show()

# %%
x = list('abcdef'.upper())

y1 = np.random.randint(1,200,6)
y2 = np.random.randint(1,200,6)

plt.plot(x,y1,linestyle='--',color='r',label="Estimated Marks",marker='o')
plt.plot(x,y2,color='g',label="Actual Marks")

plt.xlabel("Class",fontsize=20, color='r')
plt.ylabel("Avg Marks",fontsize=20,color='g')

plt.legend()

plt.grid(alpha=0.5)

for i,j in zip(x,y1):
  plt.text(i,j-4,str(j))

for i,j in zip(x,y2):
    plt.text(i,j,str(j))

plt.xticks(color='b')



plt.show()

# %%
x = list('abcdef'.upper())

y1 = np.random.randint(1,200,6)
y2 = np.random.randint(1,200,6)

plt.plot(x,y1,linestyle='--',color='r',label="Estimated Marks",marker='o')
plt.plot(x,y2,color='g',label="Actual Marks")

plt.xlabel("Class",fontsize=20, color='r')
plt.ylabel("Avg Marks",fontsize=20,color='g')

plt.legend()

plt.grid(alpha=0.5)

for i,j in zip(x,y1):
  plt.text(i,j-4,str(j))

for i,j in zip(x,y2):
    plt.text(i,j,str(j))

plt.xticks(color='b')
plt.yticks(fontsize=10)



plt.show()

# %%
x = list('abcdef'.upper())

y1 = np.random.randint(1,200,6)
y2 = np.random.randint(1,200,6)

plt.plot(x,y1,linestyle='--',color='r',label="Estimated Marks",marker='o')
plt.plot(x,y2,color='g',label="Actual Marks")

plt.xlabel("Class",fontsize=20, color='r')
plt.ylabel("Avg Marks",fontsize=20,color='g')

plt.legend()

plt.grid(alpha=0.5)

for i,j in zip(x,y1):
  plt.text(i,j-4,str(j))

for i,j in zip(x,y2):
    plt.text(i,j,str(j))

plt.xticks(color='b')
plt.yticks(fontsize=10)


plt.savefig("Class Report",dpi=1000)



plt.show()

# %%
path = r"C:\Users\Admin\Desktop\MatPlotLib"

# %%
for k in range(11):
    x = list('abcdef'.upper())
    
    y1 = np.random.randint(1,200,6)
    y2 = np.random.randint(1,200,6)
    
    plt.plot(x,y1,linestyle='--',color='r',label="Estimated Marks",marker='o')
    plt.plot(x,y2,color='g',label="Actual Marks")

    plt.title(f"My ScrorCard {k}".upper())
    
    plt.xlabel("Class",fontsize=20, color='r')
    plt.ylabel("Avg Marks",fontsize=20,color='g')
    
    plt.legend()
    
    plt.grid(alpha=0.5)
    
    for i,j in zip(x,y1):
      plt.text(i,j-4,str(j))
    
    for i,j in zip(x,y2):
        plt.text(i,j,str(j))
    
    plt.xticks(color='b')
    plt.yticks(fontsize=10)
    
    
    plt.savefig(path+f'\\image_{k}',dpi=1000)
    
    
    
    plt.show()
    display(clear=True)
