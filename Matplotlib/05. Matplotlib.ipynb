# %%
# Box Plot
# Violin plot
# Axvline
# plt.arrow
# box plot combine vilion plot
# subplot
# implot
# replot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# BOX PLOT

# %%
# it is outliers detection

# %%
# A Box Plot (also called a Box-and-Whisker Plot) is a statistical graph used to show the distribution of data.

# It summarizes data using:

# Minimum value

# Maximum value

# Median (middle value)

# Quartiles (Q1, Q2, Q3)

# %%
# It helps you understand how your data is spread and distributed

# %% [markdown]
# ![pyRvpSFlF5GxFWoAU0DdEdwOChJL88FyjTAxTAznhzTLsrcGttMEdH1jSNANMhThGqPJkMll4rOf9qAGuPlD9D8ZJRhd76ACliNWNntKH3A.jpg](attachment:89c8d96b-2f32-4419-ac3e-097e50934a73.jpg)

# %%
# Box → from Q1 to Q3 (Interquartile Range)

# Line inside box → Median

# Whiskers → Minimum and Maximum

# Dots → Outliers

# %%
data = [10, 20, 30, 40, 50, 100]

# %%
sns.boxplot(data=data)
# Out:
# <Axes: >

# %% [markdown]
# # How to Calculate Q1, Q2, Q3
# - Always sort the data in ascending order
# - Find Median (Q2) - (Median = middle value)
# - Find Q1 (Lower Quartile) - (Q1 = median of lower half (left side)
# - Find Q3 (Upper Quartile) - (Q3 = median of upper half (right side)
# -

# %% [markdown]
# ![NQOYo08yIQe-EKUO6bKR6h8J3Bu86jg-IE8wrZ5iAom1RWvOfL3rNIIm74yS83QC957rE6O7-7R2qgN2tn8zCjAtCA2G3VXr5GK72kKZTu8.jpg](attachment:ef037ff4-9410-4892-9066-57c0e26afe66.jpg)

# %% [markdown]
# ![screen_shot_2014-04-02_at_7.39.09_pm_122925.jpg](attachment:172eab24-9010-410c-b52c-4cb7c6d0a344.jpg)

# %%
# If number of values is odd → exclude median when finding Q1 & Q3

# If number of values is even → split equally into two halves

# Q2 = Median

# Q1 = Median of lower half

# Q3 = Median of upper half

# %%
y1 = np.random.randint(1,1000,10)
y2 = np.random.randint(1,2000,10)
y3 = np.random.randint(1,9000,10)

# %%
plt.boxplot(y1)
plt.show()

# %%
fig,ax = plt.subplots(2,2,figsize=(8,6))
ax[0,0].boxplot(y1)
ax[0,1].boxplot(y2)
ax[1,0].boxplot(y3)

plt.show()

# %%
fig,ax = plt.subplots(2,2,figsize=(8,6))
ax[0,0].boxplot(y1,vert=False)
ax[0,1].boxplot(y2)
ax[1,0].boxplot(y3)

plt.show()

# %%
np.random.seed()
y1 = np.random.randint(1,1000,10)
y2 = np.random.randint(1,2000,10)
y3 = np.random.randint(1,9000,10)

plt.boxplot(y1,vert=False)
plt.show()

# %%
import pandas as pd
pd.Series(y1).describe()
# Out:
# count     10.00000
# mean     508.50000
# std      291.72409
# min      126.00000
# 25%      385.75000
# 50%      427.50000
# 75%      603.75000
# max      995.00000
# dtype: float64

# %%
y1
# Out:
# array([458, 397, 983, 194, 394, 126, 383, 995, 525, 630], dtype=int32)

# %% [markdown]
# ![quartileexample2-86e1fae9d3cf48c38dc5569ec7d677d1.jpg](attachment:7a7367fb-3fa2-4aa8-984d-e03ab5534749.jpg)

# %%
# Quartiles = data ko 4 equal parts me divide karna (25%, 50%, 75%)

# %%
y4 = [10,20,30,40,50,60,80,90,100]
plt.boxplot(y4,vert=False)
plt.show()

# %%
pd.Series(y4).sort_values()
# Out:
# 0     10
# 1     20
# 2     30
# 3     40
# 4     50
# 5     60
# 6     80
# 7     90
# 8    100
# dtype: int64

# %%
y4 = [10,20,30,40,50,60,80,90,100]
plt.boxplot(y4,vert=False)
plt.axvline(10)
plt.axvline(pd.Series(y4).median(),color='r')
plt.show()

# %%
pd.Series(y4).describe()
# Out:
# count      9.000000
# mean      53.333333
# std       31.622777
# min       10.000000
# 25%       30.000000
# 50%       50.000000
# 75%       80.000000
# max      100.000000
# dtype: float64

# %%
plt.boxplot(y4,vert=False)
plt.axvline(10)
plt.axvline(30,color='g')
plt.show()

# %%
plt.boxplot(y4,vert=False)
plt.axvline(10)
plt.axvline(30,color='g')
plt.axvline(50,color='y')
plt.axvline(80,color='k')

plt.show()

# %%
pd.Series(y4).describe()
# Out:
# count      9.000000
# mean      53.333333
# std       31.622777
# min       10.000000
# 25%       30.000000
# 50%       50.000000
# 75%       80.000000
# max      100.000000
# dtype: float64

# %%
plt.boxplot(y4,vert=False)
plt.axvline(10)
plt.axvline(30,color='g')
plt.axvline(50,color='y')
plt.axvline(80,color='k')
plt.axvline(53.33,color='pink')
plt.show()

# %%
ax = plt.boxplot(y4,vert=False)
plt.hist(y4)
plt.axvline(10)
plt.axvline(30,color='g')
plt.axvline(50,color='y')
plt.axvline(80,color='k')
plt.show()

# %% [markdown]
# # Skewness

# %% [markdown]
# ![VGyiusmBHiCqMXYwxUtdQhPh7jbMnL2UCWq77qCmCWTerYWAvXjeC76Oh_l15lKq68nfDvURxZtk06CzHUw5VQgML5PslplW4hxfvvBWTeg.jpg](attachment:277da4c3-c018-4855-abbb-9414e9c1b974.jpg)

# %% [markdown]
# | Type              | Shape         | Skewness |
# | ----------------- | ------------- | -------- |
# | **Normal**        | Symmetric     | 0        |
# | **Positive Skew** | Tail on right | > 0      |
# | **Negative Skew** | Tail on left  | < 0      |

# %% [markdown]
# ![NoELwOb-Z6TGgedKjbVDBwxlW1FdJ1RZs-g_UF2_e8voMCB4yDsQJsJjH6sY8-fpeTsv36wUTFpz-L-1MZ87hLEBUDzw6stQ-gcNgtdv6Xk.jpg](attachment:af6fc770-05a1-4f08-9508-8181ee99f4ce.jpg)

# %%
y = np.random.normal(size = 1000)

# %%
plt.hist(y)
plt.show()

# %%
plt.hist(y,bins=100)
plt.boxplot(y,vert=False)
plt.show()

# %%
fig, ax = plt.subplots(2,2)
ax[0,0].hist(y,bins=100)
ax[0,1].boxplot(y)
plt.show()

# %%
ax
# Out:
# array([[<Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >]], dtype=object)

# %%
plt.boxplot(y4,vert=False)
plt.show()

# %%
pd.Series(y4).mean()
# Out:
# np.float64(53.333333333333336)

# %%
pd.Series(y4).median()
# Out:
# 50.0

# %%
 q1  = pd.Series(y4).quantile(.25)

# %%
q2 = pd.Series(y4).quantile(.5)

# %%
q3 = pd.Series(y4).quantile(.75)

# %%
q1
# Out:
# np.float64(30.0)

# %%
q2
# Out:
# np.float64(50.0)

# %%
q3
# Out:
# np.float64(80.0)

# %%
pd.Series(y4).describe()
# Out:
# count      9.000000
# mean      53.333333
# std       31.622777
# min       10.000000
# 25%       30.000000
# 50%       50.000000
# 75%       80.000000
# max      100.000000
# dtype: float64

# %%
iqr = q3 - q1

# %%
iqr
# Out:
# np.float64(50.0)

# %%
upper_cap = q3 + 1.5*iqr
lower_cap = q3 - 1.5*iqr

# %%
upper_cap
# Out:
# np.float64(155.0)

# %%
lower_cap
# Out:
# np.float64(5.0)

# %%
plt.boxplot(y4,vert=False)
plt.axvline(q1,color='r')
plt.axvline(q2,color='k')
plt.axvline(iqr,color='b')

plt.axvline(upper_cap,color='yellow')
plt.axvline(lower_cap,color='pink')
plt.show()

# %%
# IQR=Q3−Q1

# Q1 = 25% value

# Q3 = 75% value

# %%
y1 = np.random.randint(1,1000,10)
y2 = np.random.randint(1,2000,10)
y3 = np.random.randint(1,9000,10)

plt.boxplot([y1,y2,y3])
plt.show()

# %%
y1 = np.random.randint(1,1000,10)
y2 = np.random.randint(1,2000,10)
y3 = np.random.randint(1,9000,10)

plt.boxplot([y1,y2,y3],notch=True)
plt.show()

# %%
y1 = np.random.randint(1,1000,10)
y2 = np.random.randint(1,2000,10)
y3 = np.random.randint(1,9000,10)

plt.boxplot([y1,y2,y3],notch=True,)
plt.show()

# %% [markdown]
# | Parameter        | What it does                   | Example                                                |
# | ---------------- | ------------------------------ | ------------------------------------------------------ |
# | `x`              | Data to plot                   | `plt.boxplot([1,2,3,4])`                               |
# | `notch`          | Adds notch around median       | `plt.boxplot(data, notch=True)`                        |
# | `sym`            | Symbol for outliers            | `plt.boxplot(data, sym='r+')`                          |
# | `vert`           | Vertical or horizontal         | `plt.boxplot(data, vert=False)`                        |
# | `orientation`    | Same as vert (new way)         | `plt.boxplot(data, orientation='horizontal')`          |
# | `whis`           | Whisker range (IQR multiplier) | `plt.boxplot(data, whis=2)`                            |
# | `positions`      | Position of box                | `plt.boxplot(data, positions=[2])`                     |
# | `widths`         | Width of box                   | `plt.boxplot(data, widths=0.5)`                        |
# | `patch_artist`   | Fill color enabled             | `plt.boxplot(data, patch_artist=True)`                 |
# | `bootstrap`      | Median CI bootstrapping        | `plt.boxplot(data, bootstrap=1000)`                    |
# | `usermedians`    | Custom median value            | `plt.boxplot(data, usermedians=[5])`                   |
# | `conf_intervals` | Custom CI range                | `plt.boxplot(data, conf_intervals=[[2,6]])`            |
# | `meanline`       | Show mean as line              | `plt.boxplot(data, meanline=True, showmeans=True)`     |
# | `showmeans`      | Show mean point                | `plt.boxplot(data, showmeans=True)`                    |
# | `showcaps`       | Show whisker caps              | `plt.boxplot(data, showcaps=False)`                    |
# | `showbox`        | Hide/show box                  | `plt.boxplot(data, showbox=False)`                     |
# | `showfliers`     | Show outliers                  | `plt.boxplot(data, showfliers=False)`                  |
# | `boxprops`       | Style of box                   | `plt.boxplot(data, boxprops=dict(color='red'))`        |
# | `tick_labels`    | Labels on axis                 | `plt.boxplot([d1,d2], tick_labels=['A','B'])`          |
# | `flierprops`     | Style outliers                 | `plt.boxplot(data, flierprops=dict(marker='o'))`       |
# | `medianprops`    | Style median line              | `plt.boxplot(data, medianprops=dict(color='blue'))`    |
# | `meanprops`      | Style mean                     | `plt.boxplot(data, meanprops=dict(marker='D'))`        |
# | `capprops`       | Style caps                     | `plt.boxplot(data, capprops=dict(color='green'))`      |
# | `whiskerprops`   | Style whiskers                 | `plt.boxplot(data, whiskerprops=dict(linestyle='--'))` |
# | `manage_ticks`   | Auto ticks control             | `plt.boxplot(data, manage_ticks=False)`                |
# | `autorange`      | Auto range adjust              | `plt.boxplot(data, autorange=True)`                    |
# | `zorder`         | Layer order                    | `plt.boxplot(data, zorder=2)`                          |
# | `capwidths`      | Width of caps                  | `plt.boxplot(data, capwidths=0.2)`                     |
# | `label`          | Label for legend               | `plt.boxplot(data, label=['Data1'])`                   |

# %%
data = [10, 20, 30, 40, 100]

plt.boxplot(
    data,
    notch=True,
    patch_artist=True,
    showmeans=True,
    boxprops=dict(facecolor='lightblue'),
    medianprops=dict(color='red'),
    meanprops=dict(marker='D')
)

plt.title("Custom Box Plot")
plt.show()
